# %%
import nengo
import nengo_spa as spa
import pytry
import numpy as np
from random import shuffle
import random
import sys, os
import math
from IPython import display
from scipy.optimize import brute, minimize

import skopt
from skopt import gp_minimize
from skopt.space.space import Integer, Real
from skopt.plots import plot_evaluations, plot_objective

from scipy.stats import sem
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.style as style
import pickle
import os

from itertools import product



# Import our classes
sys.path.append('..')
import experiments as xps
from experiments import create_xp
from model import ExperimentRun, create_vocab
from data import Data

# %% [markdown]
# # Optimization and model parameters

# %%
D = int(96)  # the dimensionality of the vectors
PROC_FDBCK = .9
PROC_FDBCK_SYN = .005
GW_FDBCK = 1
GW_SCALE = 20 # scale the input of GW for saturation and catching very short visual stimuli
BG_THR = .1
BG_BIAS = .5
STIM_DURATION = .029
FIX_DURATION = .5
N_NEURONS_SCALE = 1
N_NEURONS_SCALE_COMBINED = .25
INTEGRATOR_RESET = False
N_SAMPLES = 10000

STARTING_SEED = 1
N_SEEDS = 10

N_BLOCKS_PER_OPERATION = 1 # default: 10
N_TRIALS_PER_DIGIT = 2 # default: 5
N_DIFFERENT_DIGITS = 4 # default: 4
N_DIFFERENT_OPERATIONS = 3 # default: 3

data_dir = "evaluate_fit/big_optimization"

# %%
def evaluation_function(params):
    
    print("params:", params)
    data = []
    
    D = params[6]*16
    
#     return 0
        
    print('Simulating...')
    for i,seed in enumerate(range(STARTING_SEED, STARTING_SEED+N_SEEDS)):
        print('\t seed '+str(i+1)+'/'+str(N_SEEDS))
        data_filename = 'run_seed'+str(seed)+'_crosstalk'+str(params[0])+'_sevid'+str(params[1])+'_nsamples'+str(params[3])+'_combscale'+str(params[4])+'_procfb'+str(params[5])+'_D'+str(D)            
        
        try:
            seed_data = pd.read_pickle(data_dir+'/'+data_filename+'.csv')

        except FileNotFoundError:
            xp = create_xp(N_BLOCKS_PER_OPERATION, N_TRIALS_PER_DIGIT, N_DIFFERENT_DIGITS, N_DIFFERENT_OPERATIONS, STIM_DURATION, FIX_DURATION, seed)
            results = ExperimentRun().run(
                n_neurons_scale=N_NEURONS_SCALE,
                n_neurons_scale_combined=params[4],
                s_crosstalk=params[0],
                s_evidence=params[1],
                n_samples=int(params[3]),
                t_senso=0,
                vocab=create_vocab(D, seed),
                xp=xp,
                integrator_reset=INTEGRATOR_RESET,
                proc_feedback=params[5],
                proc_feedback_synapse=PROC_FDBCK_SYN,
                GW_feedback=GW_FDBCK,
                GW_scale=GW_SCALE,
                BG_thr=BG_THR,
                BG_bias=BG_BIAS,
                seed=seed,
                backend="nengo_ocl",
                data_dir=data_dir,
                data_filename=data_filename,
                plt=False
            )

            seed_data = results['data'].df

            seed_data.to_pickle(data_dir+'/'+data_filename+'.csv')
        data.append(seed_data)
        
        
    data = Data(pd.concat(data))
    data.df['rt'] += params[2]*1000
    error = data.mean_differences_error(compare_errorrates=True, compare_RTs=True, tasks=range(N_DIFFERENT_OPERATIONS))
    print('rmse:', error)
    print('error rate:', data.error_rate)
    data.plot_fig2_simple(plot_humans=True)
    data.plot_fig2_chained(plot_humans=True)
    return error

res = gp_minimize(evaluation_function, 
    [
        Real(0, 1), # crosstalk
        Real(1, 30), # evidence strength
        Real(0, .3), # sensory delay
        Integer(100, 10000), # number of samples
        Real(.1, 1), # n_neurons_scale_combined
        Real(.5, 1), # processor feedback
        Integer(2, 10) # dimensions (*16)
    ],
    x0=[
        .15, # crosstalk
        15, # evidence strength
        .1, # sensory delay
        N_SAMPLES,
        N_NEURONS_SCALE_COMBINED,
        PROC_FDBCK,
        int(D/16)
    ],
    n_calls=100,
    random_state=STARTING_SEED
               
)

print(res)

with open(data_dir+"/res.pickle", 'wb') as handle:
    pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# params: [0.15, 15, 0.1, 10000, 0.25, 0.9, 6]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 401.35000000000207
# 417.20000000000266
# 416.2500000000012
# 399.0000000000035
# 564.7777777777804
# 693.812500000002
# 565.1250000000028
# 585.8888888888922
# 627.0500000000022
# 563.625000000002
# 672.0000000000017
# 568.312500000002
# rmse: 51.87656355382497
# error rate: 0.08750000000000002
# params: [0.9971848109388688, 28.04416342082111, 0.038437334378807024, 9991, 0.3124800792567785, 0.6982903636480131, 5]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 329.6373343788097
# 336.68733437880985
# 340.63733437880825
# 333.7373343788102
# 478.2065651480401
# 540.88733437881
# 501.10400104547637
# 525.48733437881
# 542.8373343788093
# 467.4373343788089
# 550.4373343788083
# 455.00876295023824
# rmse: 51.310068333263104
# error rate: 0.08750000000000002
# params: [0.6697460368034801, 28.13063305337493, 0.25389327500580516, 3201, 0.5720933436155844, 0.7217264468897784, 4]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 564.7682750058074
# 579.2462161822788
# 552.6710527835837
# 555.5182750058079
# 716.9766083391406
# 712.6154972280308
# 698.7504178629518
# 727.5043861169194
# 776.1154972280293
# 737.347820460353
# 812.599157358748
# 750.6710527835857
# rmse: 131.45637570067979
# error rate: 0.23333333333333328
# params: [0.5344139089470171, 27.50489871279776, 0.1371614423960965, 4364, 0.9452150104812633, 0.8891946181682668, 8]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 418.1614423960991
# 427.3114423960989
# 427.61144239609746
# 416.6114423960997
# 568.3281090627662
# 712.0281090627657
# 574.8281090627665
# 663.4772318697832
# 700.3379129843343
# 558.5364423960975
# 650.0281090627647
# 591.711442396098
# rmse: 63.8780523127527
# error rate: 0.09166666666666667
# params: [0.8027575039373651, 3.6912234505814, 0.15544576468256674, 8664, 0.8462322166304276, 0.9148016796970919, 4]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 513.5013202381244
# 576.2314789682832
# 564.874336111139
# 517.6222352708055
# 663.6124313492352
# 1151.445764682576
# 728.2919185287242
# nan
# nan
# 683.9124313492357
# 880.1957646825679
# 651.1124313492354
# rmse: 451.72456481412564
# error rate: 0.4833333333333333
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# params: [0.05924320130156348, 20.445313161999422, 0.1779196554894171, 6749, 0.47060909107214777, 0.5987754489923907, 4]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
#

# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 501.6424027359357
# 503.4995455930769
# 570.2495455930765
# 503.0328789264111
# 722.9281170216507
# 899.2495455930804
# 675.8995455930783
# 718.9995455930766
# nan
# 726.9281170216483
# 819.4995455930875
# 664.0450001385329
# rmse: 323.5074692329701
# error rate: 0.6375
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# params: [0.21821809316175306, 4.19067854390403, 0.04662621925641943, 2487, 0.5291054567636805, 0.6823963332832556, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 394.0151081453109
# 421.62621925642316
# 459.84050497070615
# 412.62621925642264
# 623.6262192564229
# 691.6262192564219
# 598.0547906849912
# 607.8484414786442
# 704.8262192564222
# 577.6262192564201
# 673.2625828927853
# 645.4595525897554
# rmse: 67.88239414198361
# error rate: 0.48750000000000004
# params: [0.1607146156372569, 1.43877099982687, 0.18843603306637965, 4955, 0.37103742739984014, 0.5060250032057672, 6]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 766.9360330663806
# nan
# nan
# 740.0360330663827
# nan
# 1058.4360330663808
# 986.4360330663844
# 1076.4360330663837
# nan
# nan
# 1087.4360330663849
# nan
# rmse: 781.6880560819671
# error rate: 0.925
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# params: [0.0, 10.365682780401722, 0.0, 100, 0.1, 0.8011949481941285, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 356.0000000000025
# 357.2307692307728
# 388.7500000000006
# 336.8750000000039
# 508.0000000000028
# 592.2666666666706
# 484.72727272727474
# 503.60000000000315
# 522.7142857142891
# 509.4000000000025
# 549.6666666666682
# 477.80000000000274
# rmse: 41.66921990212468
# error rate: 0.43333333333333335
# params: [1.0, 30.0, 0.0, 100, 1.0, 0.5, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 317.10000000000247
# 315.4210526315812
# 332.7222222222236
# 324.11111111111444
# 512.5000000000042
# 572.1250000000032
# 504.375000000003
# 503.8333333333369
# 544.5714285714306
# 488.66666666666737
# 516.3750000000016
# 496.7500000000024
# rmse: 55.06049313728512
# error rate: 0.32499999999999996
# params: [1.0, 30.0, 0.3, 100, 0.1, 1.0, 10]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 584.8000000000022
# 591.6250000000019
# 599.7777777777789
# 589.2000000000032
# 819.000000000003
# 867.8333333333343
# 822.5625000000034
# 941.3333333333363
# 825.0000000000002
# 768.5882352941201
# 788.0000000000019
# 755.9500000000023
# rmse: 180.98209604217774
# error rate: 0.30833333333333335
# params: [1.0, 17.532951352871535, 0.0, 100, 1.0, 0.6216636802217026, 8]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 277.15000000000225
# 282.4000000000025
# 281.58823529411865
# 274.6000000000032
# 439.533333333336
# 502.9444444444468
# 440.1250000000042
# 499.90000000000293
# 500.6315789473703
# 420.80000000000075
# 487.7777777777793
# 431.0000000000017
# rmse: 81.28368494361034
# error rate: 0.15416666666666667
# params: [1.0, 30.0, 0.0, 7175, 0.1, 0.870843380219801, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 355.2222222222245
# 351.0588235294139
# 357.14285714285853
# 355.83333333333604
# 486.00000000000296
# 537.3000000000037
# 476.66666666667106
# 559.7500000000031
# 561.4444444444466
# 509.07692307692565
# 543.3000000000022
# 500.10000000000235
# rmse: 42.98897682987416
# error rate: 0.38749999999999996
# params: [0.5770743802658704, 20.34555532938718, 0.0, 10000, 1.0, 0.6057345412787231, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 351.05555555555685
# 329.50000000000233
# 329.5000000000012
# 333.26666666666983
# 451.2500000000043
# 584.3750000000027
# 480.5000000000012
# 506.93333333333703
# 559.7500000000024
# 449.00000000000045
# 531.3529411764723
# 509.2857142857159
# rmse: 54.74275084069
# error rate: 0.3916666666666667
# params: [0.5735485935505419, 14.706126803421602, 0.035402312288350134, 1119, 0.9926666545257626, 1.0, 5]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 355.60231228835266
# 345.0023122883528
# 340.40231228835097
# 349.35231228835323
# 571.777312288353
# 553.9023122883576
# 530.0176969037383
# 555.0023122883523
# 651.902312288354
# 543.9023122883518
# 565.1165980026387
# 610.2148122883525
# rmse: 54.61965177743689
# error rate: 0.37083333333333335
# params: [1.0, 30.0, 0.3, 10000, 0.1, 0.5, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 620.8000000000022
# 640.1111111111134
# 642.9375000000009
# 625.8235294117677
# 823.666666666672
# 887.6666666666699
# 791.6250000000036
# 832.1333333333367
# 843.6000000000021
# 739.2500000000002
# 827.4375000000019
# 781.250000000002
# rmse: 181.56187565694674
# error rate: 0.3375
# params: [0.0, 6.259439179535826, 0.3, 100, 1.0, 0.5, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 655.7000000000021
# 653.6428571428593
# 677.9285714285724
# 658.4000000000034
# 808.2000000000037
# 903.250000000003
# 884.4545454545482
# 885.0000000000035
# 874.8333333333356
# 811.0000000000008
# 898.9285714285733
# 879.8333333333353
# rmse: 213.55943233510104
# error rate: 0.37083333333333335
# params: [0.7458263993249413, 25.090735168250735, 0.0, 1271, 0.9141333636828762, 1.0, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 383.1333333333353
# 339.1428571428601
# 364.13333333333446
# 419.450000000003
# 618.3076923076956
# 514.4285714285761
# 518.7272727272762
# 606.6666666666703
# nan
# 582.6666666666673
# 585.8571428571439
# 494.8888888888913
# rmse: 301.34620390159523
# error rate: 0.48750000000000004
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# params: [0.46043141163870044, 13.317909413869671, 0.00907203555969751, 3212, 0.2579943864815899, 0.8726135289853247, 4]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 337.8498133374776
# 382.0220355596993
# 349.62759111525395
# 329.79425778192217
# 497.2863212739859
# 608.2258817135465
# 467.3220355597009
# 542.5335740212394
# 631.0720355596997
# 520.9951124827764
# 622.9387022263653
# 465.2863212739858
# rmse: 52.57669249544291
# error rate: 0.22083333333333333
# params: [0.08333645222722574, 8.572199890431092, 0.02750136784609269, 5278, 0.626416314298506, 0.7288006209715132, 2]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 355.723590068317
# 384.56386784609583
# 407.21565356037934
# 373.3763678460961
# 533.1680345127616
# 616.5638678460953
# 497.37636784609595
# 568.6831860279143
# 664.2705986153258
# 531.0727964175233
# 583.8763678460944
# 588.001367846095
# rmse: 46.10215044241569
# error rate: 0.3916666666666667
# params: [0.9118411829163331, 24.370421815616478, 0.019309143016308167, 5957, 0.6599434895065909, 0.5151363673337727, 7]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 297.8591430163106
# 295.6591430163106
# 301.3591430163093
# 300.15914301631125
# 437.309143016311
# 503.90914301631074
# 437.375809682978
# 490.3091430163111
# 526.3091430163101
# 468.80914301630946
# 524.3091430163093
# 477.7091430163117
# rmse: 70.08264489030807
# error rate: 0.18333333333333335
# params: [0.0, 30.0, 0.0, 10000, 0.1, 0.8730458696935166, 10]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 282.7000000000023
# 298.3500000000027
# 303.1500000000011
# 284.55000000000325
# 506.6666666666696
# 451.65000000000265
# 430.6111111111148
# 437.7894736842135
# 453.30000000000217
# 432.7647058823539
# 488.40000000000134
# 459.33333333333536
# rmse: 79.18962014569044
# error rate: 0.04166666666666663
# params: [0.5928203560185278, 21.64140575246894, 0.0, 9298, 0.42364165880949667, 0.7728801402296797, 10]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 276.5500000000024
# 283.0000000000022
# 284.9500000000011
# 275.6500000000036
# 423.647058823532
# 475.4000000000031
# 416.5000000000028
# 463.8000000000031
# 468.3157894736858
# 424.4666666666673
# 473.2000000000015
# 435.4444444444464
# rmse: 85.53887996302436
# error rate: 0.07916666666666672
# params: [0.9106987358124199, 9.770977714335624, 0.0, 1701, 0.9247778309787635, 0.9222811224398988, 10]
# Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# running run_seed10_crosstalk0.9106987358124199_sevid9.770977714335624_nsamples1701_combscale0.9247778309787635_procfb0.9222811224398988_D160
# No context argument was provided to nengo_ocl.Simulator
# Calling pyopencl.create_some_context() for you now:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 10
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.9247778309787635
# s_crosstalk = 0.9106987358124199
# s_evidence = 9.770977714335624
# n_samples = 1701
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed7c1a5350>
# xp = <experiments.Xp1 object at 0x7fed7bffb3d0>
# proc_feedback = 0.9222811224398988
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fed6894fd50>
# 288.40000000000236
# 322.9000000000024
# 317.0555555555562
# 282.8000000000031
# 425.1666666666694
# 849.5000000000008
# 445.5294117647093
# nan
# 532.5000000000033
# 441.9444444444454
# 785.1000000000022
# 429.4500000000019
# rmse: 317.19612520990637
# error rate: 0.3125
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# params: [0.0, 30.0, 0.0, 10000, 0.1, 0.5, 2]
# Simulating...
# 	 seed 1/10
# running run_seed1_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=11, similarity=0.12)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=13, similarity=0.13)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=14, similarity=0.14)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15, similarity=0.16)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.13)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.12)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=18, similarity=0.18)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=19, similarity=0.16)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=20, similarity=0.20)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.1
# s_crosstalk = 0.0
# s_evidence = 30.0
# n_samples = 10000
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed37fe3a50>
# xp = <experiments.Xp1 object at 0x7fed508b4e10>
# proc_feedback = 0.5
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fed36a00250>
# 	 seed 2/10
# running run_seed2_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=12, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=13, similarity=0.12)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=14, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.14)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.13)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=18, similarity=0.14)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=19, similarity=0.11)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.1
# s_crosstalk = 0.0
# s_evidence = 30.0
# n_samples = 10000
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed3653c490>
# xp = <experiments.Xp1 object at 0x7fed5045fd50>
# proc_feedback = 0.5
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fed563bfb10>
# 	 seed 3/10
# running run_seed3_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=9, similarity=0.10)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=10, similarity=0.13)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=12, similarity=0.13)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=14, similarity=0.16)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15, similarity=0.15)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.10)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=18, similarity=0.16)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=19, similarity=0.20)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=20, similarity=0.13)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.1
# s_crosstalk = 0.0
# s_evidence = 30.0
# n_samples = 10000
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed506f4510>
# xp = <experiments.Xp1 object at 0x7fed68cbec10>
# proc_feedback = 0.5
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fed7be79e10>
# 	 seed 4/10
# running run_seed4_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=13, similarity=0.14)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=14, similarity=0.12)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15, similarity=0.17)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.14)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=18, similarity=0.17)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=20, similarity=0.15)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.1
# s_crosstalk = 0.0
# s_evidence = 30.0
# n_samples = 10000
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed78735490>
# xp = <experiments.Xp1 object at 0x7fed235ceed0>
# proc_feedback = 0.5
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fed68cc6090>
# 	 seed 5/10
# running run_seed5_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=11, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=13, similarity=0.11)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15, similarity=0.19)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.17)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.17)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=19, similarity=0.19)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=20, similarity=0.19)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.1
# s_crosstalk = 0.0
# s_evidence = 30.0
# n_samples = 10000
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed7c370510>
# xp = <experiments.Xp1 object at 0x7fed7c2e3c50>
# proc_feedback = 0.5
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fed37c5c250>
# 	 seed 6/10
# running run_seed6_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=12, similarity=0.10)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=15, similarity=0.12)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.18)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.18)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=20, similarity=0.16)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# seed = 6
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# n_neurons_scale_combined = 0.1
# s_crosstalk = 0.0
# s_evidence = 30.0
# n_samples = 10000
# t_senso = 0
# vocab = <nengo_spa.vocabulary.Vocabulary object at 0x7fed1ad52a90>
# xp = <experiments.Xp1 object at 0x7fed7c3a2850>
# proc_feedback = 0.5
# proc_feedback_synapse = 0.005
# GW_feedback = 1
# GW_threshold = 0.5
# GW_scale = 20
# BG_thr = 0.1
# BG_bias = 0.5
# integrator_reset = False
# data = <data.Data object at 0x7fecf9e12410>
# 	 seed 7/10
# running run_seed7_crosstalk0.0_sevid30.0_nsamples10000_combscale0.1_procfb0.5_D32
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=12, similarity=0.14)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=16, similarity=0.16)
#   len(self._key2idx), best_sim))
# /home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_spa/vocabulary.py:173: UserWarning: Could not create a semantic pointer with max_similarity=0.10 (D=32, M=17, similarity=0.16)
#   len(self._key2idx), best_sim))
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
