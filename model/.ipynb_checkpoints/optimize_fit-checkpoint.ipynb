# %%
import nengo
import nengo_spa as spa
import pytry
import numpy as np
from random import shuffle
import random
import sys, os
import math
from IPython import display
from scipy.optimize import brute, minimize

import skopt
from skopt import gp_minimize
from skopt.space.space import Integer, Real
from skopt.plots import plot_evaluations, plot_objective

from scipy.stats import sem
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.style as style
import pickle
import os

from itertools import product



# Import our classes
sys.path.append('..')
import experiments as xps
from experiments import create_xp
from model import ExperimentRun, create_vocab
from data import Data

# %% [markdown]
# # Optimization and model parameters

# %%
D = int(96)  # the dimensionality of the vectors
PROC_FDBCK = .9
PROC_FDBCK_SYN = .005
GW_FDBCK = 1
GW_SCALE = 20 # scale the input of GW for saturation and catching very short visual stimuli
BG_THR = .1
BG_BIAS = .5
STIM_DURATION = .029
FIX_DURATION = .5
N_NEURONS_SCALE = 1
N_NEURONS_SCALE_COMBINED = .25
INTEGRATOR_RESET = False
N_SAMPLES = 10000

STARTING_SEED = 1
N_SEEDS = 10

N_BLOCKS_PER_OPERATION = 1 # default: 10
N_TRIALS_PER_DIGIT = 2 # default: 5
N_DIFFERENT_DIGITS = 4 # default: 4
N_DIFFERENT_OPERATIONS = 3 # default: 3

data_dir = "evaluate_fit/big_optimization_2"

# %%
errors = []

def evaluation_function(params):
    
    print("params:", params)
    data = []
    
    D = params[6]*16
    
#     return 0
        
    print('Simulating...')
    for i,seed in enumerate(range(STARTING_SEED, STARTING_SEED+N_SEEDS)):
        print('\t seed '+str(i+1)+'/'+str(N_SEEDS))
        data_filename = 'run_seed'+str(seed)+'_crosstalk'+str(params[0])+'_sevid'+str(params[1])+'_nsamples'+str(params[3])+'_combscale'+str(params[4])+'_procfb'+str(params[5])+'_D'+str(D)+'_gwscale'+str(params[7])+'_prevsyn'+str(params[8])      
        print(data_filename)
        try:
            seed_data = pd.read_pickle(data_dir+'/'+data_filename+'.csv')

        except FileNotFoundError:
            xp = create_xp(N_BLOCKS_PER_OPERATION, N_TRIALS_PER_DIGIT, N_DIFFERENT_DIGITS, N_DIFFERENT_OPERATIONS, STIM_DURATION, FIX_DURATION, seed)
            results = ExperimentRun().run(
                n_neurons_scale=N_NEURONS_SCALE,
                n_neurons_scale_combined=params[4],
                s_crosstalk=params[0],
                s_evidence=params[1],
                n_samples=int(params[3]),
                t_senso=0,
                vocab=create_vocab(D, seed),
                xp=xp,
                integrator_reset=INTEGRATOR_RESET,
                proc_feedback=params[5],
                proc_feedback_synapse=PROC_FDBCK_SYN,
                prev_feedback_synapse=params[8],
                GW_feedback=GW_FDBCK,
                GW_scale=params[7],
                BG_thr=BG_THR,
                BG_bias=BG_BIAS,
                seed=seed,
                backend="nengo_ocl",
                data_dir=data_dir,
                data_filename=data_filename,
                plt=False
            )

            seed_data = results['data'].df

            seed_data.to_pickle(data_dir+'/'+data_filename+'.csv')
        data.append(seed_data)
        
        
    data = Data(pd.concat(data))
    data.df['rt'] += params[2]*1000
    error = data.mean_differences_error(compare_errorrates=True, compare_RTs=True, tasks=range(N_DIFFERENT_OPERATIONS))
    print('rmse:', error)
#     data.plot_fig2_simple(plot_humans=True)
#     data.plot_fig2_chained(plot_humans=True)
    return error

res = gp_minimize(evaluation_function, 
    dimensions=[
        Real(0, 1, name="crosstalk"), # crosstalk
        Real(5, 20, name="evidence strength"), # evidence strength
        Real(0, .2, name="senso"), # sensory delay
        Integer(100, 10000, name="number of samples"), # number of samples
        Real(.1, 1, name="scale combined"), # n_neurons_scale_combined
        Real(.5, 1, name="processor feedback"), # processor feedback
        Integer(2, 10, name="dimensions"), # dimensions (*16)
        Real(1, 30, name="GW scale"), # GW scale
        Real(.002, .02, name="PREV feedback synapse"), # PREV feedback synapse
    ],
    x0=[
        .15, # crosstalk
        15, # evidence strength
        .1, # sensory delay
        N_SAMPLES,
        N_NEURONS_SCALE_COMBINED,
        PROC_FDBCK,
        int(D/16),
        GW_SCALE,
        .01 # prev fb syn
    ],
    n_calls=100,
    random_state=STARTING_SEED
               
)

print(res)

with open(data_dir+"/res.pickle", 'wb') as handle:
    pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# params: [0.15, 15, 0.1, 10000, 0.25, 0.9, 6, 20, 0.01]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 2/10
# run_seed2_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 3/10
# run_seed3_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 4/10
# run_seed4_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 5/10
# run_seed5_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 6/10
# run_seed6_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 7/10
# run_seed7_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 8/10
# run_seed8_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 9/10
# run_seed9_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# 	 seed 10/10
# run_seed10_crosstalk0.15_sevid15_nsamples10000_combscale0.25_procfb0.9_D96_gwscale20_prevsyn0.01
# rmse: 40.03263923191786
# error rate: 0.07499999999999996
# params: [0.9971848109388688, 18.988360390079883, 0.025624889585871353, 9991, 0.3124800792567785, 0.6982903636480131, 5, 20.422635067300924, 0.018839703274508582]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 2/10
# run_seed2_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 3/10
# run_seed3_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 4/10
# run_seed4_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 5/10
# run_seed5_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 6/10
# run_seed6_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 7/10
# run_seed7_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 8/10
# run_seed8_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 9/10
# run_seed9_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# 	 seed 10/10
# run_seed10_crosstalk0.9971848109388688_sevid18.988360390079883_nsamples9991_combscale0.3124800792567785_procfb0.6982903636480131_D80_gwscale20.422635067300924_prevsyn0.018839703274508582
# rmse: 45.859745043411586
# error rate: 0.21250000000000002
# params: [0.8463109166860173, 9.699102753984128, 0.10490963191457431, 4490, 0.30661949235684305, 0.7672069544735085, 9, 14.258939431622663, 0.009752574209324755]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 2/10
# run_seed2_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 3/10
# run_seed3_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 4/10
# run_seed4_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 5/10
# run_seed5_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 6/10
# run_seed6_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 7/10
# run_seed7_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 8/10
# run_seed8_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 9/10
# run_seed9_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# 	 seed 10/10
# run_seed10_crosstalk0.8463109166860173_sevid9.699102753984128_nsamples4490_combscale0.30661949235684305_procfb0.7672069544735085_D144_gwscale14.258939431622663_prevsyn0.009752574209324755
# rmse: 43.96436692450899
# error rate: 0.1958333333333333
# params: [0.939127789423626, 16.675838545048006, 0.14319410319367287, 8047, 0.18352072777666414, 0.7590762744709445, 9, 25.045260313647113, 0.016932860469095312]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 2/10
# run_seed2_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 3/10
# run_seed3_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 4/10
# run_seed4_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 5/10
# run_seed5_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 6/10
# run_seed6_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 7/10
# run_seed7_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 8/10
# run_seed8_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 9/10
# run_seed9_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# 	 seed 10/10
# run_seed10_crosstalk0.939127789423626_sevid16.675838545048006_nsamples8047_combscale0.18352072777666414_procfb0.7590762744709445_D144_gwscale25.045260313647113_prevsyn0.016932860469095312
# rmse: 62.534259546891555
# error rate: 0.19999999999999996
# params: [0.2730499742167474, 5.888648019523452, 0.13410560801378912, 5971, 0.704488687679921, 0.7058939394845265, 4, 9.399259575828562, 0.004558162438549226]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 2/10
# run_seed2_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 3/10
# run_seed3_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 4/10
# run_seed4_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 5/10
# run_seed5_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 6/10
# run_seed6_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 7/10
# run_seed7_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 8/10
# run_seed8_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 9/10
# run_seed9_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# 	 seed 10/10
# run_seed10_crosstalk0.2730499742167474_sevid5.888648019523452_nsamples5971_combscale0.704488687679921_procfb0.7058939394845265_D64_gwscale9.399259575828562_prevsyn0.004558162438549226
# rmse: 49.87724894069418
# error rate: 0.25
# params: [0.7833144726948864, 11.188082622545394, 0.006834262237167811, 6278, 0.6945721572142027, 0.6492476473765224, 6, 7.441611878525871, 0.003320555091366793]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 2/10
# run_seed2_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 3/10
# run_seed3_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 4/10
# run_seed4_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 5/10
# run_seed5_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 6/10
# run_seed6_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 7/10
# run_seed7_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 8/10
# run_seed8_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 9/10
# run_seed9_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# 	 seed 10/10
# run_seed10_crosstalk0.7833144726948864_sevid11.188082622545394_nsamples6278_combscale0.6945721572142027_procfb0.6492476473765224_D96_gwscale7.441611878525871_prevsyn0.003320555091366793
# rmse: 125.27610710423741
# error rate: 0.11250000000000004
# params: [0.46923852643814323, 6.442583906681925, 0.18067403329577353, 1283, 0.5723194391834011, 0.5418115022735132, 9, 27.40300307199995, 0.007380742019774892]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 2/10
# run_seed2_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 3/10
# run_seed3_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 4/10
# run_seed4_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 5/10
# run_seed5_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 6/10
# run_seed6_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 7/10
# run_seed7_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 8/10
# run_seed8_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 9/10
# run_seed9_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# 	 seed 10/10
# run_seed10_crosstalk0.46923852643814323_sevid6.442583906681925_nsamples1283_combscale0.5723194391834011_procfb0.5418115022735132_D144_gwscale27.40300307199995_prevsyn0.007380742019774892
# rmse: 82.50918397613243
# error rate: 0.22499999999999998
# params: [0.5843891207379293, 13.488680411962898, 0.12278766355921117, 9570, 0.3348810816540012, 0.6155077111062945, 6, 28.548206017446557, 0.01087507268380543]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 2/10
# run_seed2_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 3/10
# run_seed3_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 4/10
# run_seed4_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 5/10
# run_seed5_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 6/10
# run_seed6_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 7/10
# run_seed7_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 8/10
# run_seed8_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 9/10
# run_seed9_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# 	 seed 10/10
# run_seed10_crosstalk0.5843891207379293_sevid13.488680411962898_nsamples9570_combscale0.3348810816540012_procfb0.6155077111062945_D96_gwscale28.548206017446557_prevsyn0.01087507268380543
# rmse: 36.107924759133915
# error rate: 0.07499999999999996
# params: [0.5406005088236441, 16.482276566613066, 0.00906914571493065, 1486, 0.8131632272164174, 0.5149006790911966, 9, 16.68285749842798, 0.01006364326556753]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 2/10
# run_seed2_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 3/10
# run_seed3_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 4/10
# run_seed4_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 5/10
# run_seed5_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 6/10
# run_seed6_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 7/10
# run_seed7_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 8/10
# run_seed8_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 9/10
# run_seed9_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# 	 seed 10/10
# run_seed10_crosstalk0.5406005088236441_sevid16.482276566613066_nsamples1486_combscale0.8131632272164174_procfb0.5149006790911966_D144_gwscale16.68285749842798_prevsyn0.01006364326556753
# rmse: 81.87390267141897
# error rate: 0.0
# params: [0.8921358720018813, 10.663765117266422, 0.10768493885599704, 6558, 0.4251349181904589, 0.7855042805925463, 7, 4.663131666301762, 0.014423682579592615]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 2/10
# run_seed2_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 3/10
# run_seed3_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 4/10
# run_seed4_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 5/10
# run_seed5_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 6/10
# run_seed6_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 7/10
# run_seed7_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 8/10
# run_seed8_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 9/10
# run_seed9_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# 	 seed 10/10
# run_seed10_crosstalk0.8921358720018813_sevid10.663765117266422_nsamples6558_combscale0.4251349181904589_procfb0.7855042805925463_D112_gwscale4.663131666301762_prevsyn0.014423682579592615
# rmse: 55.76860216422348
# error rate: 0.15416666666666667
# params: [0.6477493997733477, 10.30908633197453, 0.15264661054302442, 3630, 0.777509517858044, 0.9406709148170056, 2, 15.445163019218862, 0.0033282562052117833]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 2/10
# run_seed2_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 3/10
# run_seed3_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 4/10
# run_seed4_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 5/10
# run_seed5_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 6/10
# run_seed6_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 7/10
# run_seed7_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 8/10
# run_seed8_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 9/10
# run_seed9_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# 	 seed 10/10
# run_seed10_crosstalk0.6477493997733477_sevid10.30908633197453_nsamples3630_combscale0.777509517858044_procfb0.9406709148170056_D32_gwscale15.445163019218862_prevsyn0.0033282562052117833
# rmse: 62.84511773583794
# error rate: 0.5041666666666667
# params: [0.5311258544103719, 6.094190497202908, 0.07242655391174176, 100, 0.9397819972104736, 0.5, 10, 30.0, 0.02]
# Simulating...
# 	 seed 1/10
# run_seed1_crosstalk0.5311258544103719_sevid6.094190497202908_nsamples100_combscale0.9397819972104736_procfb0.5_D160_gwscale30.0_prevsyn0.02
# running run_seed1_crosstalk0.5311258544103719_sevid6.094190497202908_nsamples100_combscale0.9397819972104736_procfb0.5_D160_gwscale30.0_prevsyn0.02
# No context argument was provided to nengo_ocl.Simulator
# Calling pyopencl.create_some_context() for you now:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-bdbdf0d9f995> in evaluation_function(params)
#      17         try:
# ---> 18             seed_data = pd.read_pickle(data_dir+'/'+data_filename+'.csv')
#      19
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     169         compression = None
# --> 170     f, fh = get_handle(fp_or_buf, "rb", compression=compression, is_text=False)
#     171
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     460             # Binary mode
# --> 461             f = open(path_or_buf, mode)
#     462         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'evaluate_fit/big_optimization_2/run_seed1_crosstalk0.5311258544103719_sevid6.094190497202908_nsamples100_combscale0.9397819972104736_procfb0.5_D160_gwscale30.0_prevsyn0.02.csv'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     100         for subnetwork in network.networks:
# --> 101             model.build(subnetwork)
#     102
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     100         for subnetwork in network.networks:
# --> 101             model.build(subnetwork)
#     102
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     100         for subnetwork in network.networks:
# --> 101             model.build(subnetwork)
#     102
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     112             # is in a subnetwork?
# --> 113             model.build(conn)
#     114
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/connection.py in build_connection(model, conn)
#     257         eval_points, weights, solver_info = model.build(
# --> 258             conn.solver, conn, rng, transform)
#     259         if conn.solver.weights:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/connection.py in build_solver(model, solver, conn, rng, transform)
#     163 def build_solver(model, solver, conn, rng, transform):
# --> 164     return build_decoders(model, conn, rng, transform)
#     165
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/connection.py in build_decoders(model, conn, rng, transform)
#     107     eval_points = get_eval_points(model, conn, rng)
# --> 108     targets = get_targets(conn, eval_points)
#     109
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/connection.py in get_targets(conn, eval_points)
#      82                                  "None. Cannot solve for decoders." % (conn,))
# ---> 83             targets[i] = out
#      84
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bdbdf0d9f995> in <module>
#      93     ],
#      94     n_calls=100,
# ---> 95     random_state=STARTING_SEED
#      96
#      97 )
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     269         n_restarts_optimizer=n_restarts_optimizer,
#     270         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 271         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     270     for n in range(n_calls):
#     271         next_x = optimizer.ask()
# --> 272         next_y = func(next_x)
#     273         result = optimizer.tell(next_x, next_y)
#     274         result.specs = specs
#
# <ipython-input-3-bdbdf0d9f995> in evaluation_function(params)
#      41                 data_dir=data_dir,
#      42                 data_filename=data_filename,
# ---> 43                 plt=False
#      44             )
#      45
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/pytry-0.9.2-py3.7.egg/pytry/trial.py in run(self, **kwargs)
#      89         random.seed(p.seed)
#      90
# ---> 91         result = self.execute_trial(p)
#      92
#      93         if result is None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/pytry-0.9.2-py3.7.egg/pytry/nengo.py in execute_trial(self, p)
#     110                                      **extra_args)
#     111             else:
# --> 112                 self.sim = Simulator(model, dt=p.dt, **extra_args)
#     113
#     114             with self.sim:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_ocl/simulator.py in __init__(self, network, dt, seed, model, context, n_prealloc_probes, profiling, if_python_code, planner, progress_bar)
#     236             if network is not None:
#     237                 # Build the network into the model
# --> 238                 self.model.build(network)
#     239
#     240         logger.info("Nengo build in %0.3f s" % nengo_timer.duration)
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     121             The object to build into this model.
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#     125             self.build_callback(obj)
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     216                 "Cannot build object of type %r" % type(obj).__name__)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#     220     @classmethod
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     122         if model.toplevel is network:
#     123             progress.step()
# --> 124             model.build_callback = None
#     125
#     126     # Unset config
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in __exit__(self, exc_type, exc_value, traceback)
#     513         self._close_fd()
#     514         if self._index is not None:
# --> 515             rval = self._index.__exit__(exc_type, exc_value, traceback)
#     516             return rval
#     517
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in __exit__(self, exc_type, exc_value, traceback)
#     367
#     368     def __exit__(self, exc_type, exc_value, traceback):
# --> 369         self.sync()
#     370
#     371     def _reinit(self):
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in sync(self)
#     442                                if v[0] not in self._removed_files}
#     443
# --> 444                 self._write_index()
#     445         except TimeoutError:
#     446             warnings.warn(
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in _write_index(self)
#     399             pickle.dump(self._index, f, pickle.HIGHEST_PROTOCOL)
#     400         try:
# --> 401             replace(self.index_path + '.part', self.index_path)
#     402         except CalledProcessError:
#     403             # May happen with Python 2.7 on Windows where replace is
#
# KeyboardInterrupt:

# %%
[0.6477493997733477, 10.30908633197453, 0.15264661054302442, 3630, 0.777509517858044, 0.9406709148170056, 2, 15.445163019218862, 0.0033282562052117833]
# Out:
# [0.6477493997733477,
#  10.30908633197453,
#  0.15264661054302442,
#  3630,
#  0.777509517858044,
#  0.9406709148170056,
#  2,
#  15.445163019218862,
#  0.0033282562052117833]
