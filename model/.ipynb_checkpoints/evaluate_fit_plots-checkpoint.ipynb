# %%
import nengo
import nengo_spa as spa
import pytry
import numpy as np
from random import shuffle
import random
import sys, os
import math
from IPython import display
from scipy.optimize import brute, minimize
from scipy.stats import sem
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.style as style

import os

from itertools import product



# Import our classes
sys.path.append('..')
import experiments as xps
from experiments import create_xp
from model import ExperimentRun, create_vocab
from data import Data

# %% [markdown]
# # Optimization and model parameters

# %%
D = int(96)  # the dimensionality of the vectors
PROC_FDBCK = .9
PROC_FDBCK_SYN = .005
GW_FDBCK = 1
GW_SCALE = 20 # scale the input of GW for saturation and catching very short visual stimuli
BG_THR = .1
BG_BIAS = .5
STIM_DURATION = .029
FIX_DURATION = .5
N_NEURONS_SCALE = 1
N_NEURONS_SCALE_COMBINED = .25
INTEGRATOR_RESET = False
N_SAMPLES = 10000

N_BLOCKS_PER_OPERATION = 1 # default: 10
N_TRIALS_PER_DIGIT = 2 # default: 5
N_DIFFERENT_DIGITS = 4 # default: 4
N_DIFFERENT_OPERATIONS = 3 # default: 3

data_dir = "evaluate_fit/fit_no_threshold"

# %%
t_sensos = [0]#np.linspace(.05, .2, 5)
s_evids = np.linspace(5, 15, 3)
crosstalks = np.linspace(.05, .25, 5)
print(s_evids)
print(crosstalks)

STARTING_SEED = 1
N_SEEDS = 10

rmses = np.zeros((len(t_sensos), len(s_evids), len(crosstalks)))

for j in range(4):

    plt.figure(figsize=(18,18))

    i=0
    for condition in product(*tuple([range(len(param_values)) for param_values in [t_sensos, s_evids, crosstalks]])):
        i+=1
        print('condition ', i, '/', rmses.size, ':', condition)  
        print('\t sensory delay:', t_sensos[condition[0]]*1000)
        print('\t evidence strength:', s_evids[condition[1]])
        print('\t crosstalk:', crosstalks[condition[2]])
        data = []

        if True:

            print('\t Simulating...')
            for i,seed in enumerate(range(STARTING_SEED, STARTING_SEED+N_SEEDS)):
                print('\t seed '+str(i+1)+'/'+str(N_SEEDS))
                data_filename = 'run_seed'+str(seed)+'_sevid'+str(s_evids[condition[1]])+'_crosstalk'+str(crosstalks[condition[2]])         

                try:
                    seed_data = pd.read_pickle(data_dir+'/'+data_filename+'.csv')

                except FileNotFoundError:
                    xp = create_xp(N_BLOCKS_PER_OPERATION, N_TRIALS_PER_DIGIT, N_DIFFERENT_DIGITS, N_DIFFERENT_OPERATIONS, STIM_DURATION, FIX_DURATION, seed)
                    results = ExperimentRun().run(
                        n_neurons_scale=N_NEURONS_SCALE,
                        n_neurons_scale_combined=N_NEURONS_SCALE_COMBINED,
                        s_evidence=s_evids[condition[1]],
                        s_crosstalk=crosstalks[condition[2]],
                        n_samples=N_SAMPLES,
                        vocab=create_vocab(D, seed),
                        xp=xp,
                        integrator_reset=True,
                        proc_feedback=PROC_FDBCK,
                        proc_feedback_synapse=PROC_FDBCK_SYN,
                        GW_feedback=GW_FDBCK,
                        GW_scale=GW_SCALE,
                        BG_thr=BG_THR,
                        BG_bias=BG_BIAS,
                        seed=seed,
                        backend="nengo_ocl",
                        data_dir=data_dir,
                        data_filename=data_filename,
                        plt=False
                    )
                    seed_data = results['data'].df
                    seed_data.to_pickle(data_dir+'/'+data_filename+'.csv')

                data.append(seed_data)


            data = Data(pd.concat(data))
            data.df['rt'] += t_sensos[condition[0]]*1000 # add sensory delay to reaction times

            rmse_fitness_error = data.rmse_fitness_error(compare_errorrates=False, compare_RTs=True, tasks=range(N_DIFFERENT_OPERATIONS))
            print('\t rmse:', rmse_fitness_error[0])
            print('\t error rate:', data.error_rate)
            
            plt.subplot(len(s_evids), len(crosstalks))
            if j==0:
                data.plot_fig2_simple(plot_humans=True, save_file=data_dir+'/'+data_filename, errorates=False, show=False)
            elif j==1:
                data.plot_fig2_simple(plot_humans=True, save_file=data_dir+'/'+data_filename, rts=False, show=False)
            if j==2:
                data.plot_fig2_chained(plot_humans=True, save_file=data_dir+'/'+data_filename, errorates=False, show=False)
            elif j==3:
                data.plot_fig2_chained(plot_humans=True, save_file=data_dir+'/'+data_filename, rts=False, show=False)

            rmses[condition] = rmse_fitness_error[0]
            
    plt.show()
# Out:
# [ 5. 10. 15.]
# [0.05 0.1  0.15 0.2  0.25]
# condition  1 / 15 : (0, 0, 0)
# 	 sensory delay: 0
# 	 evidence strength: 5.0
# 	 crosstalk: 0.05
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 140.29932605783324
# 	 error rate: 0.32499999999999996
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 0, 1)
# 	 sensory delay: 0
# 	 evidence strength: 5.0
# 	 crosstalk: 0.1
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 136.34047674082532
# 	 error rate: 0.3375
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 0, 2)
# 	 sensory delay: 0
# 	 evidence strength: 5.0
# 	 crosstalk: 0.15000000000000002
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 133.71000588717305
# 	 error rate: 0.375
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 0, 3)
# 	 sensory delay: 0
# 	 evidence strength: 5.0
# 	 crosstalk: 0.2
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 133.22615941117462
# 	 error rate: 0.35416666666666663
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 0, 4)
# 	 sensory delay: 0
# 	 evidence strength: 5.0
# 	 crosstalk: 0.25
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 138.62621181666393
# 	 error rate: 0.375
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 1, 0)
# 	 sensory delay: 0
# 	 evidence strength: 10.0
# 	 crosstalk: 0.05
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 96.34199578382565
# 	 error rate: 0.10416666666666663
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 1, 1)
# 	 sensory delay: 0
# 	 evidence strength: 10.0
# 	 crosstalk: 0.1
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 97.101124933345
# 	 error rate: 0.11250000000000004
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 1, 2)
# 	 sensory delay: 0
# 	 evidence strength: 10.0
# 	 crosstalk: 0.15000000000000002
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 106.00205173026795
# 	 error rate: 0.12083333333333335
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 1, 3)
# 	 sensory delay: 0
# 	 evidence strength: 10.0
# 	 crosstalk: 0.2
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 110.8469643322516
# 	 error rate: 0.14166666666666672
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 1, 4)
# 	 sensory delay: 0
# 	 evidence strength: 10.0
# 	 crosstalk: 0.25
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 126.23673238517893
# 	 error rate: 0.15416666666666667
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 2, 0)
# 	 sensory delay: 0
# 	 evidence strength: 15.0
# 	 crosstalk: 0.05
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 95.36435055127288
# 	 error rate: 0.07916666666666672
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 2, 1)
# 	 sensory delay: 0
# 	 evidence strength: 15.0
# 	 crosstalk: 0.1
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 99.07476224084633
# 	 error rate: 0.0708333333333333
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 2, 2)
# 	 sensory delay: 0
# 	 evidence strength: 15.0
# 	 crosstalk: 0.15000000000000002
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 101.4201665529172
# 	 error rate: 0.09166666666666667
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 2, 3)
# 	 sensory delay: 0
# 	 evidence strength: 15.0
# 	 crosstalk: 0.2
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 107.58072375909171
# 	 error rate: 0.09999999999999998
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# condition  10 / 15 : (0, 2, 4)
# 	 sensory delay: 0
# 	 evidence strength: 15.0
# 	 crosstalk: 0.25
# 	 Simulating...
# 	 seed 1/10
# 	 seed 2/10
# 	 seed 3/10
# 	 seed 4/10
# 	 seed 5/10
# 	 seed 6/10
# 	 seed 7/10
# 	 seed 8/10
# 	 seed 9/10
# 	 seed 10/10
# 	 rmse: 113.62564999146917
# 	 error rate: 0.08750000000000002
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
