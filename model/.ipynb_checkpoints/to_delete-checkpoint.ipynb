# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
running_times = np.array([01.39, 01.50, 01.39, 01.38, 01.42, 01.39, 01.39, 01.41, 01.39, 01.39, 01.46, 02.02, 02.03, 01.55, 01.41, 01.41, 01.44, 01.51, 01.54, 01.58, 02.03, 02.03, 01.57, 02.01, 02.04, 02.03, 02.03, 02.01, 02.04, 02.01, 02.17, 02.15, 02.15, 02.16, 02.17, 02.19, 02.18, 02.17, 02.17, 02.17, 02.37, 03.13, 03.14, 03.12, 03.12, 03.13, 03.14, 03.15, 03.08, 03.11, 03.10, 02.56, 02.45, 02.49, 02.52, 02.57, 02.54, 02.57, 02.57, 02.55, 03.13, 03.16, 03.17, 03.32, 03.40, 03.41, 03.39, 03.39, 03.38, 03.38, 03.41, 03.29, 03.31, 03.33, 03.31, 03.59, 04.13, 03.51, 03.24, 03.52, 04.23, 04.12, 04.04, 03.56, 03.59, 03.56, 03.53, 03.58, 03.49, 03.50])
frac_part, int_part = np.modf(running_times)
# running_times = int_part + frac_part/.6 # in minutes
running_times = int_part*60 + frac_part*100 # in sec

# %%
first_running_times = running_times[:90].reshape(-1,10).mean(axis=1)

# %%
plt.plot(range(9), first_running_times)
plt.show()

# %%
plt.plot(range(8), first_running_times)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1768c28a13c5> in <module>()
# ----> 1 plt.plot(range(8), first_running_times)
#       2 plt.show()
#
# /home/ubuntu/anaconda3/envs/ANMC/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# /home/ubuntu/anaconda3/envs/ANMC/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1868                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1869                         RuntimeWarning, stacklevel=2)
# -> 1870             return func(ax, *args, **kwargs)
#    1871
#    1872         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.plot(np.linspace(-10,10,50))
plt.plot(np.linspace(-10,10,50))

plt.show()
