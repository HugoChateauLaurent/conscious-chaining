# %%
import nengo
import nengo_spa as spa
import pytry
import numpy as np
from random import shuffle
import random
import sys, os
import math
from IPython import display
from scipy.optimize import brute, minimize
from scipy.stats import sem
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.style as style

import os



# Import our classes
sys.path.append('..')
import experiments as xps
from experiments import create_xp
from model import ExperimentRun, create_vocab
from data import Data

# %% [markdown]
# # Optimization and model parameters

# %%
D = int(96)  # the dimensionality of the vectors
PROC_FDBCK = .9
PROC_FDBCK_SYN = .005
GW_FDBCK = 1
GW_SCALE = 20 # scale the input of GW for saturation and catching very short visual stimuli
BG_THR = .1
BG_BIAS = .5
STIM_DURATION = .1
FIX_DURATION = .5
N_NEURONS_SCALE = 1
N_SEEDS = 8
STARTING_SEED = 100

N_BLOCKS_PER_OPERATION = 1 # default: 10
N_TRIALS_PER_DIGIT = 2 # default: 5
N_DIFFERENT_DIGITS = 4 # default: 4
N_DIFFERENT_OPERATIONS = 1 # default: 3

data_dir = "evaluate_fit/s_evid_20_threshold_controlled"

# %%
# def evaluation_function(params):
    
#     print("params:", params)
#     data = []
    
# #     return 0
        
#     print('Simulating...')
#     for i,seed in enumerate(range(STARTING_SEED, STARTING_SEED+N_SEEDS)):
#         print('\t seed '+str(i+1)+'/'+str(N_SEEDS))
#         data_filename = 'run_seed'+str(seed)+'_sevid'+str(params[0])            
        
#         xp = create_xp(N_BLOCKS_PER_OPERATION, N_TRIALS_PER_DIGIT, N_DIFFERENT_DIGITS, N_DIFFERENT_OPERATIONS, STIM_DURATION, FIX_DURATION, seed)
#         results = ExperimentRun().run(
#             n_neurons_scale=N_NEURONS_SCALE,
#             s_crosstalk=0,
#             s_evidence=params[0],
#             t_senso=0,
#             vocab=create_vocab(D, seed),
#             xp=xp,
#             integrator_reset=True,
#             proc_feedback=PROC_FDBCK,
#             proc_feedback_synapse=PROC_FDBCK_SYN,
#             GW_feedback=GW_FDBCK,
#             GW_scale=GW_SCALE,
#             BG_thr=BG_THR,
#             BG_bias=BG_BIAS,
#             seed=seed,
#             backend="nengo_ocl",
#             data_dir=data_dir,
#             data_filename=data_filename,
#             plt=False
#         )
#         seed_data = results['data'].df

#         seed_data.to_pickle(data_dir+'/'+data_filename+'.csv')
#         data.append(seed_data)
        
        
#     data = Data(pd.concat(data))
#     data.plot_fig2_simple()
#     rmse_fitness_error = data.rmse_fitness_error(compare_errorrates=False, compare_RTs=True, tasks=range(N_DIFFERENT_OPERATIONS))
#     print('rmse:', rmse_fitness_error)
#     print('error rate:', data.error_rate)
#     return rmse_fitness_error[0]

    
# x0, fval, grid, jout = brute(
#     evaluation_function, 
#     (
#         (10,11), # evidence strength
#     ),
#     Ns=1, 
#     full_output=True,
#     finish=None
# )

# print(x0, fval, grid, jout)
# np.save(data_dir+"/x0_2", x0)
# np.save(data_dir+"/fval_2", fval)
# np.save(data_dir+"/grid_2", grid)
# np.save(data_dir+"/jout_2", jout)

# %%
all_data = []
def offline_evaluation_function(params):
    
    print("params:", params)
    data = []
    
#     return 0
        
    print('Simulating...')
    for i,seed in enumerate(range(STARTING_SEED, STARTING_SEED+N_SEEDS)):
        print('\t seed '+str(i+1)+'/'+str(N_SEEDS))
        data_filename = 'run_seed'+str(seed)+'_sevid'+str(params[0])    
        print(data_dir+'/'+data_filename+'.csv')
        seed_data = pd.read_pickle(data_dir+'/'+data_filename+'.csv')
        data.append(seed_data)
        
        
    data = Data(pd.concat(data))
    data.plot_fig2_simple()
#     data.df['rt'] += params[1] # add sensory delay
    rmse_fitness_error = data.rmse_fitness_error(compare_errorrates=False, compare_RTs=True, tasks=range(N_DIFFERENT_OPERATIONS))
    print('rmse:', rmse_fitness_error)
    print('error rate:', data.error_rate)
    return rmse_fitness_error[0]
    
x0, fval, grid, jout = brute(
    offline_evaluation_function, 
    (
        (20,21), # evidence strength
#         (0, .5) # sensory processing delay
    ),
    Ns=1, 
    full_output=True,
    finish=None
)

all_data = Data(pd.concat(all_data))
# Out:
# params: [20.]
# Simulating...
# 	 seed 1/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed100_sevid20.0.csv
# 	 seed 2/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed101_sevid20.0.csv
# 	 seed 3/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed102_sevid20.0.csv
# 	 seed 4/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed103_sevid20.0.csv
# 	 seed 5/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed104_sevid20.0.csv
# 	 seed 6/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed105_sevid20.0.csv
# 	 seed 7/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed106_sevid20.0.csv
# 	 seed 8/8
# evaluate_fit/s_evid_20_threshold_controlled/run_seed107_sevid20.0.csv
# 4
# 16
# rmse: (127.4991206696327, [], [3503.4106721563057, 3045.8937421337814, 1168.9298595152045, 1309.688324526462, 3157.272974639311, 2723.7560446168363, 7087.8914847973765, 10037.95920488767, 39279.12399044076, 40880.64092046306, 94980.83956606135, 101882.01112362466, 6113.616089763409, 5653.478392246603, 40880.64092046334, 45877.19171053155, 1281.1638447086268, 1583.5106380577784, 149.00232451860668, 116.49638627632334, 829.0569563475601, 829.0569563475863, 2006.4441297442688, 2893.7244147800375, 21548.287360148486, 19263.593773449873, 70115.51776394853, 77725.73154067126, 4328.7647948274, 5897.218476537494, 31610.47500860403, 27487.43462855653, 3182.5298162712597, 1553.4567030637875, 1116.489721931731, 865.1784011770148, 21.032174761933064, 31.204344573239492, 179.93311815813766, 596.0392502335807, 1798.940193629833, 2248.079344573216, 0.34349551664290956, 184.58170306381837, 596.039250233625, 502.3835898563174, 9685.29868419587, 7817.020382309421, 9422.893761622097, 10014.323307076673, 6735.746034349247, 7933.748307076465, 5339.457397985552, 5051.1710343493505, 2122.591488894706, 6900.889216167638, 9815.18012525824, 9229.750579803675, 101169.53694343993, 110936.68467071213, 5635.743761621917, 5486.600579803583, 19901.193761621962, 19063.76421616726])
# error rate: 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-fcbd0378976e> in <module>
#      32     Ns=1,
#      33     full_output=True,
# ---> 34     finish=None
#      35 )
#      36
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/scipy/optimize/optimize.py in brute(func, ranges, args, Ns, full_output, finish, disp, workers)
#    2897     xmin = zeros(N, float)
#    2898     for k in range(N - 1, -1, -1):
# -> 2899         thisN = Nshape[k]
#    2900         Nindx[k] = indx % Nshape[k]
#    2901         indx = indx // thisN
#
# IndexError: tuple index out of range

# %%
print(x0, fval, grid, jout)

# %%
plt.matshow(jout, cmap='gray')
plt.show()

plt.plot(jout.mean(axis=0), label=0)
plt.plot(jout.mean(axis=1), label=1)
plt.legend()
plt.show()

# plt.plot(jout)

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.color'] = "black"
mpl.rcParams['font.size'] = 15
mpl.rcParams['errorbar.capsize'] = 3


accuracies = np.array([all_data.df.loc[all_data.df['dim'] == dim]['acc'].to_list() for dim in grid*16])
accuracies = 100-100*accuracies
means = accuracies.mean(axis=1)
sems = sem(accuracies, axis=1)

accuracies_simple = np.array([all_data.df.loc[(all_data.df['dim'] == dim) & (all_data.df['rule'] == 0)]['acc'].to_list() for dim in grid*16])
accuracies_simple = 100-100*accuracies_simple
means_simple = accuracies_simple.mean(axis=1)
sems_simple = sem(accuracies_simple, axis=1)

accuracies_chained = np.array([all_data.df.loc[(all_data.df['dim'] == dim) & (all_data.df['rule'] != 0)]['acc'].to_list() for dim in grid*16])
accuracies_chained = 100-100*accuracies_chained
means_chained = accuracies_chained.mean(axis=1)
sems_chained = sem(accuracies_chained, axis=1)


plt.errorbar(grid*16, means_chained, sems_chained, color="black", label='Chained', linestyle='dotted')
plt.errorbar(grid*16, means, sems, color="black", label='All')
plt.errorbar(grid*16, means_simple, sems_simple, color="black", label='Simple', linestyle='-.')
plt.xlabel('Number of dimensions')
plt.ylabel('Error rate (%)')
plt.xticks(grid*16)
plt.ylim(bottom=0)
plt.yticks(range(0,90,10))
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')
plt.legend()

plt.show()

# %%
print(all_data.df['suj'])
df_save = all_data.df.copy()
for i in range(20):
    
    all_data = Data(df_save.loc[df_save['suj'] == i+1])

    accuracies = np.array([all_data.df.loc[all_data.df['dim'] == dim]['acc'].to_list() for dim in grid*16])
    accuracies = 100-100*accuracies
    means = accuracies.mean(axis=1)
    sems = sem(accuracies, axis=1)

    accuracies_simple = np.array([all_data.df.loc[(all_data.df['dim'] == dim) & (all_data.df['rule'] == 0)]['acc'].to_list() for dim in grid*16])
    accuracies_simple = 100-100*accuracies_simple
    means_simple = accuracies_simple.mean(axis=1)
    sems_simple = sem(accuracies_simple, axis=1)

    accuracies_chained = np.array([all_data.df.loc[(all_data.df['dim'] == dim) & (all_data.df['rule'] != 0)]['acc'].to_list() for dim in grid*16])
    accuracies_chained = 100-100*accuracies_chained
    means_chained = accuracies_chained.mean(axis=1)
    sems_chained = sem(accuracies_chained, axis=1)


    plt.errorbar(grid*16, means_chained, sems_chained, color="black", label='Chained', linestyle='dotted')
    plt.errorbar(grid*16, means, sems, color="black", label='All')
    plt.errorbar(grid*16, means_simple, sems_simple, color="black", label='Simple', linestyle='-.')
    plt.xlabel('Number of dimensions')
    plt.ylabel('Error rate (%)')
    plt.xticks(grid*16)
    plt.ylim(bottom=0, top=100)
    plt.yticks(range(0,90,10))
    plt.gca().spines['right'].set_color('none')
    plt.gca().spines['top'].set_color('none')
    plt.legend()

    plt.show()
