# %%
import nengo
import nengo_spa as spa
import numpy as np
from itertools import product
import pytry
import matplotlib.pyplot as plt
import pickle
from os import path
from scipy.stats import sem

# %%
class ExperimentRun(pytry.NengoTrial):
    def params(self):
        self.param('scaling of the number of neurons', n_neurons_scale=1)
        self.param('integrator evidence strength', s_evidence=20)
        self.param('vector dimensions', D=None)
        self.param('whether to reset the comparison integrator at the beginning of each trial', integrator_reset=True)
        self.param('simulation time', T=.2)
        self.param('stimulus to compare', stimulus='')
        self.param('number of samples', n_samples=1000)

    def make_n_neurons_per_dim(self, p):
        # Number of neurons
        n_neurons_per_dim = { # initialize to default values then scale
            module: int(number*p.n_neurons_scale) for module,number in { 
            'AM': 50,
            'Ensemble': 50,
            'State': 50,
            'BG': 100,
            'thal_1': 50,
            'thal_2': 40,
            'Scalar': 50 # this is for the whole module (one dim)
        }.items()}

        return n_neurons_per_dim

    def model(self, p):
        
        rng = np.random.RandomState(p.seed)
        
        vocab = spa.Vocabulary(p.D)
        stimuli = ['D'+str(s) for s in range(2,9)]
        rng.shuffle(stimuli)
        vocab.populate(';'.join(stimuli))
        print('stimuli', stimuli)
        
        n_neurons_per_dim = self.make_n_neurons_per_dim(p)
        with spa.Network(seed=p.seed) as model:
            inp = spa.Transcode(
                lambda t: 'D'+str(p.stimulus),
                output_vocab=vocab
            )
            COM = DirectCompareProcessor(
                vocab, 
                n_neurons_per_dim, 
                rng,
                p.n_samples
            )
            inp >> COM.input
            self.probes = {'compared': nengo.Probe(COM.compared, synapse=.01)}
        return model

    def evaluate_behaviour(self, sim, p, seed):

        print('compare shape', sim.data[self.probes['compared']].shape)
        mean_comparison = np.mean(sim.data[self.probes['compared']])
        return dict(mean_comparison=mean_comparison)

    def evaluate(self, p, sim, plt):
        sim.run(p.T)
        data = self.evaluate_behaviour(sim, p, p.seed)
        return data
    
class DirectCompareProcessor(spa.Network):

    def __init__(
        self, 
        vocab, 
        n_neurons_per_dim,
        rng,
        n_samples,
        input_AM_thr=0,
        add_ON=True,
        **kwargs
        ):

        super(DirectCompareProcessor, self).__init__(**kwargs)

        with self:
            
            n_neurons = int(n_neurons_per_dim['Ensemble'])

            D = vocab.dimensions

            self.a = spa.Transcode(input_vocab=vocab, output_vocab=vocab, label="a")
            self.clean_b = nengo.Node([1]) # constant input for our task (5)
            self.input = self.a.input # for our task

            self.clean_a = self.a
            
            train_vectors = np.zeros((n_samples, 2*D))
            train_coords = np.zeros((n_samples, 1))
            xs, ys = rng.choice(range(2,8+1), size=n_samples), rng.choice(range(2,8+1), size=n_samples)
            for i in range(n_samples):
                train_vectors[i, :D] = vocab.parse("D"+str(xs[i])).v
                train_vectors[i, D:] = vocab.parse("D"+str(ys[i])).v
                train_coords[i, 0] = -1 if xs[i]<ys[i] else 1 if xs[i]>ys[i] else 0

            self.combined = nengo.Ensemble(2*D*n_neurons, 2*D)
            nengo.Connection(self.clean_a.output, self.combined[:D])
            nengo.Connection(self.clean_b, self.combined[D:], function=lambda x: x*vocab.parse('D5').v)

            self.compared = nengo.Node(size_in=1)
            nengo.Connection(
                self.combined,
                self.compared,
                function=train_coords,
                eval_points=train_vectors,
                scale_eval_points=False,
                synapse=None
              )


        self.declare_input(self.input, vocab)

# %%
data_dir = 'evaluate_compare/all'

# %%
seeds = list(range(30))
n_neurons_scales = [.5,1]#,1.5]#,2]
Ds = [96,192]
stimuli = [2,4,6,8]
ns_samples = [100,1000]#,10000]

mean_comparisons = np.zeros((len(seeds), len(n_neurons_scales), len(Ds), len(stimuli), len(ns_samples)))

i=0
for condition in product(*tuple([range(len(param_values)) for param_values in [seeds, n_neurons_scales, Ds, stimuli, ns_samples]])):
    i+=1
    print('condition ', i, '/', mean_comparisons.size, ':', condition)    
    
    data_filename = 'run_seed'+str(seeds[condition[0]])+'_nscale'+str(n_neurons_scales[condition[1]])+'_D'+str(Ds[condition[2]])+'_stim'+str(stimuli[condition[3]])+'_nsamples'+str(ns_samples[condition[4]])
    
    try:
        mean_comparison = pickle.load(open(data_dir+'/'+data_filename, "rb"))
    
    except FileNotFoundError:
        try:
            mean_comparison = ExperimentRun().run(
                seed=seeds[condition[0]],
                n_neurons_scale=n_neurons_scales[condition[1]],
                D=Ds[condition[2]],
                stimulus=stimuli[condition[3]],
                n_samples=ns_samples[condition[4]],
                backend="nengo_ocl",
                data_dir=data_dir,
                data_filename=data_filename,
            )['mean_comparison']

            pickle.dump(mean_comparison, open(data_dir+'/'+data_filename, "wb"))
        
        except MemoryError:
            print('Memory error', seeds[condition[0]], n_neurons_scales[condition[1]], Ds[condition[2]], stimuli[condition[3]], ns_samples[condition[4]])
            mean_comparison = np.nan
    
    mean_comparisons[condition] = mean_comparison
    print(mean_comparison)
# Out:
# condition  1 / 960 : (0, 0, 0, 0, 0)
# -0.8778784
# condition  2 / 960 : (0, 0, 0, 0, 1)
# -0.8100098
# condition  3 / 960 : (0, 0, 0, 1, 0)
# -0.69126374
# condition  4 / 960 : (0, 0, 0, 1, 1)
# -0.7229607
# condition  5 / 960 : (0, 0, 0, 2, 0)
# 0.75994855
# condition  6 / 960 : (0, 0, 0, 2, 1)
# 0.6915436
# condition  7 / 960 : (0, 0, 0, 3, 0)
# 0.82588774
# condition  8 / 960 : (0, 0, 0, 3, 1)
# 0.8612518
# condition  9 / 960 : (0, 0, 1, 0, 0)
# -0.8924786
# condition  10 / 960 : (0, 0, 1, 0, 1)
# -0.85832167
# condition  11 / 960 : (0, 0, 1, 1, 0)
# -0.71729684
# condition  12 / 960 : (0, 0, 1, 1, 1)
# -0.7396674
# condition  13 / 960 : (0, 0, 1, 2, 0)
# 0.76659167
# condition  14 / 960 : (0, 0, 1, 2, 1)
# 0.69703645
# condition  15 / 960 : (0, 0, 1, 3, 0)
# 0.85749334
# condition  16 / 960 : (0, 0, 1, 3, 1)
# 0.8631886
# condition  17 / 960 : (0, 1, 0, 0, 0)
# -0.88762426
# condition  18 / 960 : (0, 1, 0, 0, 1)
# -0.8687839
# condition  19 / 960 : (0, 1, 0, 1, 0)
# -0.8096828
# condition  20 / 960 : (0, 1, 0, 1, 1)
# -0.77909577
# condition  21 / 960 : (0, 1, 0, 2, 0)
# 0.82560194
# condition  22 / 960 : (0, 1, 0, 2, 1)
# 0.7931439
# condition  23 / 960 : (0, 1, 0, 3, 0)
# 0.8954211
# condition  24 / 960 : (0, 1, 0, 3, 1)
# 0.86528695
# condition  25 / 960 : (0, 1, 1, 0, 0)
# -0.8906971
# condition  26 / 960 : (0, 1, 1, 0, 1)
# -0.8533197
# condition  27 / 960 : (0, 1, 1, 1, 0)
# -0.7747406
# condition  28 / 960 : (0, 1, 1, 1, 1)
# -0.7974928
# condition  29 / 960 : (0, 1, 1, 2, 0)
# 0.82282275
# condition  30 / 960 : (0, 1, 1, 2, 1)
# 0.765334
# condition  31 / 960 : (0, 1, 1, 3, 0)
# 0.8841111
# condition  32 / 960 : (0, 1, 1, 3, 1)
# 0.88506025
# condition  33 / 960 : (1, 0, 0, 0, 0)
# -0.7743088
# condition  34 / 960 : (1, 0, 0, 0, 1)
# -0.8461148
# condition  35 / 960 : (1, 0, 0, 1, 0)
# -0.6232047
# condition  36 / 960 : (1, 0, 0, 1, 1)
# -0.6626882
# condition  37 / 960 : (1, 0, 0, 2, 0)
# 0.69450575
# condition  38 / 960 : (1, 0, 0, 2, 1)
# 0.73436856
# condition  39 / 960 : (1, 0, 0, 3, 0)
# 0.8090837
# condition  40 / 960 : (1, 0, 0, 3, 1)
# 0.84357923
# condition  41 / 960 : (1, 0, 1, 0, 0)
# -0.8892661
# condition  42 / 960 : (1, 0, 1, 0, 1)
# -0.87929285
# condition  43 / 960 : (1, 0, 1, 1, 0)
# -0.63890654
# condition  44 / 960 : (1, 0, 1, 1, 1)
# -0.7024013
# condition  45 / 960 : (1, 0, 1, 2, 0)
# 0.70891297
# condition  46 / 960 : (1, 0, 1, 2, 1)
# 0.7212528
# condition  47 / 960 : (1, 0, 1, 3, 0)
# 0.857666
# condition  48 / 960 : (1, 0, 1, 3, 1)
# 0.8657944
# condition  49 / 960 : (1, 1, 0, 0, 0)
# -0.9077745
# condition  50 / 960 : (1, 1, 0, 0, 1)
# -0.8736875
# condition  51 / 960 : (1, 1, 0, 1, 0)
# -0.690923
# condition  52 / 960 : (1, 1, 0, 1, 1)
# -0.7762464
# condition  53 / 960 : (1, 1, 0, 2, 0)
# 0.75763166
# condition  54 / 960 : (1, 1, 0, 2, 1)
# 0.7916263
# condition  55 / 960 : (1, 1, 0, 3, 0)
# 0.8648256
# condition  56 / 960 : (1, 1, 0, 3, 1)
# 0.8847561
# condition  57 / 960 : (1, 1, 1, 0, 0)
# -0.8816998
# condition  58 / 960 : (1, 1, 1, 0, 1)
# -0.89906603
# condition  59 / 960 : (1, 1, 1, 1, 0)
# -0.736954
# condition  60 / 960 : (1, 1, 1, 1, 1)
# -0.7458874
# condition  61 / 960 : (1, 1, 1, 2, 0)
# 0.7710211
# condition  62 / 960 : (1, 1, 1, 2, 1)
# 0.77102286
# condition  63 / 960 : (1, 1, 1, 3, 0)
# 0.86950564
# condition  64 / 960 : (1, 1, 1, 3, 1)
# 0.865055
# condition  65 / 960 : (2, 0, 0, 0, 0)
# -0.88987076
# condition  66 / 960 : (2, 0, 0, 0, 1)
# -0.87409866
# condition  67 / 960 : (2, 0, 0, 1, 0)
# -0.75162673
# condition  68 / 960 : (2, 0, 0, 1, 1)
# -0.7533329
# condition  69 / 960 : (2, 0, 0, 2, 0)
# 0.7727293
# condition  70 / 960 : (2, 0, 0, 2, 1)
# 0.6602242
# condition  71 / 960 : (2, 0, 0, 3, 0)
# 0.845116
# condition  72 / 960 : (2, 0, 0, 3, 1)
# 0.85788965
# condition  73 / 960 : (2, 0, 1, 0, 0)
# -0.8777927
# condition  74 / 960 : (2, 0, 1, 0, 1)
# -0.87100106
# condition  75 / 960 : (2, 0, 1, 1, 0)
# -0.76686525
# condition  76 / 960 : (2, 0, 1, 1, 1)
# -0.7623175
# condition  77 / 960 : (2, 0, 1, 2, 0)
# 0.78069246
# condition  78 / 960 : (2, 0, 1, 2, 1)
# 0.6729365
# condition  79 / 960 : (2, 0, 1, 3, 0)
# 0.80493146
# condition  80 / 960 : (2, 0, 1, 3, 1)
# 0.8561816
# condition  81 / 960 : (2, 1, 0, 0, 0)
# -0.8996674
# condition  82 / 960 : (2, 1, 0, 0, 1)
# -0.9157335
# condition  83 / 960 : (2, 1, 0, 1, 0)
# -0.8435683
# condition  84 / 960 : (2, 1, 0, 1, 1)
# -0.80856985
# condition  85 / 960 : (2, 1, 0, 2, 0)
# 0.830219
# condition  86 / 960 : (2, 1, 0, 2, 1)
# 0.79321504
# condition  87 / 960 : (2, 1, 0, 3, 0)
# 0.8904923
# condition  88 / 960 : (2, 1, 0, 3, 1)
# 0.8694861
# condition  89 / 960 : (2, 1, 1, 0, 0)
# -0.89390177
# condition  90 / 960 : (2, 1, 1, 0, 1)
# -0.8827454
# condition  91 / 960 : (2, 1, 1, 1, 0)
# -0.8561922
# condition  92 / 960 : (2, 1, 1, 1, 1)
# -0.82584167
# condition  93 / 960 : (2, 1, 1, 2, 0)
# 0.8411325
# condition  94 / 960 : (2, 1, 1, 2, 1)
# 0.7559211
# condition  95 / 960 : (2, 1, 1, 3, 0)
# 0.8590422
# condition  96 / 960 : (2, 1, 1, 3, 1)
# 0.8654796
# condition  97 / 960 : (3, 0, 0, 0, 0)
# -0.70222884
# condition  98 / 960 : (3, 0, 0, 0, 1)
# -0.8401514
# condition  99 / 960 : (3, 0, 0, 1, 0)
# -0.6159279
# condition  100 / 960 : (3, 0, 0, 1, 1)
# -0.7592578
# condition  101 / 960 : (3, 0, 0, 2, 0)
# 0.59781414
# condition  102 / 960 : (3, 0, 0, 2, 1)
# 0.77741045
# condition  103 / 960 : (3, 0, 0, 3, 0)
# 0.82954377
# condition  104 / 960 : (3, 0, 0, 3, 1)
# 0.8261131
# condition  105 / 960 : (3, 0, 1, 0, 0)
# -0.8127303
# condition  106 / 960 : (3, 0, 1, 0, 1)
# -0.8539622
# condition  107 / 960 : (3, 0, 1, 1, 0)
# -0.61788154
# condition  108 / 960 : (3, 0, 1, 1, 1)
# -0.6832494
# condition  109 / 960 : (3, 0, 1, 2, 0)
# 0.49413162
# condition  110 / 960 : (3, 0, 1, 2, 1)
# 0.70850265
# condition  111 / 960 : (3, 0, 1, 3, 0)
# 0.73945
# condition  112 / 960 : (3, 0, 1, 3, 1)
# 0.82510394
# condition  113 / 960 : (3, 1, 0, 0, 0)
# -0.77496666
# condition  114 / 960 : (3, 1, 0, 0, 1)
# -0.8699561
# condition  115 / 960 : (3, 1, 0, 1, 0)
# -0.69904417
# condition  116 / 960 : (3, 1, 0, 1, 1)
# -0.7909767
# condition  117 / 960 : (3, 1, 0, 2, 0)
# 0.66395646
# condition  118 / 960 : (3, 1, 0, 2, 1)
# 0.8052637
# condition  119 / 960 : (3, 1, 0, 3, 0)
# 0.8124287
# condition  120 / 960 : (3, 1, 0, 3, 1)
# 0.8577128
# condition  121 / 960 : (3, 1, 1, 0, 0)
# -0.6581849
# condition  122 / 960 : (3, 1, 1, 0, 1)
# -0.857009
# condition  123 / 960 : (3, 1, 1, 1, 0)
# -0.7321727
# condition  124 / 960 : (3, 1, 1, 1, 1)
# -0.78999066
# condition  125 / 960 : (3, 1, 1, 2, 0)
# 0.6704004
# condition  126 / 960 : (3, 1, 1, 2, 1)
# 0.7908055
# condition  127 / 960 : (3, 1, 1, 3, 0)
# 0.85548645
# condition  128 / 960 : (3, 1, 1, 3, 1)
# 0.89411455
# condition  129 / 960 : (4, 0, 0, 0, 0)
# -0.8615474
# condition  130 / 960 : (4, 0, 0, 0, 1)
# -0.83162504
# condition  131 / 960 : (4, 0, 0, 1, 0)
# -0.7944439
# condition  132 / 960 : (4, 0, 0, 1, 1)
# -0.70988786
# condition  133 / 960 : (4, 0, 0, 2, 0)
# 0.63522863
# condition  134 / 960 : (4, 0, 0, 2, 1)
# 0.72272307
# condition  135 / 960 : (4, 0, 0, 3, 0)
# 0.8714058
# condition  136 / 960 : (4, 0, 0, 3, 1)
# 0.8379376
# condition  137 / 960 : (4, 0, 1, 0, 0)
# -0.8425993
# condition  138 / 960 : (4, 0, 1, 0, 1)
# -0.807084
# condition  139 / 960 : (4, 0, 1, 1, 0)
# -0.7972525
# condition  140 / 960 : (4, 0, 1, 1, 1)
# -0.6876464
# condition  141 / 960 : (4, 0, 1, 2, 0)
# 0.6119665
# condition  142 / 960 : (4, 0, 1, 2, 1)
# 0.7298628
# condition  143 / 960 : (4, 0, 1, 3, 0)
# 0.89565796
# condition  144 / 960 : (4, 0, 1, 3, 1)
# 0.8672521
# condition  145 / 960 : (4, 1, 0, 0, 0)
# -0.88985854
# condition  146 / 960 : (4, 1, 0, 0, 1)
# -0.8666094
# condition  147 / 960 : (4, 1, 0, 1, 0)
# -0.8426235
# condition  148 / 960 : (4, 1, 0, 1, 1)
# -0.7854777
# condition  149 / 960 : (4, 1, 0, 2, 0)
# 0.73651004
# condition  150 / 960 : (4, 1, 0, 2, 1)
# 0.78091776
# condition  151 / 960 : (4, 1, 0, 3, 0)
# 0.87850523
# condition  152 / 960 : (4, 1, 0, 3, 1)
# 0.85729676
# condition  153 / 960 : (4, 1, 1, 0, 0)
# -0.90635353
# condition  154 / 960 : (4, 1, 1, 0, 1)
# -0.866261
# condition  155 / 960 : (4, 1, 1, 1, 0)
# -0.856711
# condition  156 / 960 : (4, 1, 1, 1, 1)
# -0.7663247
# condition  157 / 960 : (4, 1, 1, 2, 0)
# 0.6854419
# condition  158 / 960 : (4, 1, 1, 2, 1)
# 0.78725004
# condition  159 / 960 : (4, 1, 1, 3, 0)
# 0.878668
# condition  160 / 960 : (4, 1, 1, 3, 1)
# 0.87443995
# condition  161 / 960 : (5, 0, 0, 0, 0)
# -0.8291762
# condition  162 / 960 : (5, 0, 0, 0, 1)
# -0.84556997
# condition  163 / 960 : (5, 0, 0, 1, 0)
# -0.61417603
# condition  164 / 960 : (5, 0, 0, 1, 1)
# -0.7716184
# condition  165 / 960 : (5, 0, 0, 2, 0)
# 0.7542981
# condition  166 / 960 : (5, 0, 0, 2, 1)
# 0.675445
# condition  167 / 960 : (5, 0, 0, 3, 0)
# 0.87835455
# condition  168 / 960 : (5, 0, 0, 3, 1)
# 0.8696595
# condition  169 / 960 : (5, 0, 1, 0, 0)
# -0.8774458
# condition  170 / 960 : (5, 0, 1, 0, 1)
# -0.83781236
# condition  171 / 960 : (5, 0, 1, 1, 0)
# -0.5950601
# condition  172 / 960 : (5, 0, 1, 1, 1)
# -0.6716248
# condition  173 / 960 : (5, 0, 1, 2, 0)
# 0.76802886
# condition  174 / 960 : (5, 0, 1, 2, 1)
# 0.66900736
# condition  175 / 960 : (5, 0, 1, 3, 0)
# 0.9054805
# condition  176 / 960 : (5, 0, 1, 3, 1)
# 0.8488081
# condition  177 / 960 : (5, 1, 0, 0, 0)
# -0.87872607
# condition  178 / 960 : (5, 1, 0, 0, 1)
# -0.84791625
# condition  179 / 960 : (5, 1, 0, 1, 0)
# -0.7417204
# condition  180 / 960 : (5, 1, 0, 1, 1)
# -0.7793581
# condition  181 / 960 : (5, 1, 0, 2, 0)
# 0.8309545
# condition  182 / 960 : (5, 1, 0, 2, 1)
# 0.7850232
# condition  183 / 960 : (5, 1, 0, 3, 0)
# 0.8954642
# condition  184 / 960 : (5, 1, 0, 3, 1)
# 0.8767267
# condition  185 / 960 : (5, 1, 1, 0, 0)
# -0.8818682
# condition  186 / 960 : (5, 1, 1, 0, 1)
# -0.85123247
# condition  187 / 960 : (5, 1, 1, 1, 0)
# -0.70301986
# condition  188 / 960 : (5, 1, 1, 1, 1)
# -0.74556625
# condition  189 / 960 : (5, 1, 1, 2, 0)
# 0.8242386
# condition  190 / 960 : (5, 1, 1, 2, 1)
# 0.75872827
# condition  191 / 960 : (5, 1, 1, 3, 0)
# 0.87967837
# condition  192 / 960 : (5, 1, 1, 3, 1)
# 0.8803346
# condition  193 / 960 : (6, 0, 0, 0, 0)
# -0.8726314
# condition  194 / 960 : (6, 0, 0, 0, 1)
# -0.8330992
# condition  195 / 960 : (6, 0, 0, 1, 0)
# -0.7810773
# condition  196 / 960 : (6, 0, 0, 1, 1)
# -0.7422897
# condition  197 / 960 : (6, 0, 0, 2, 0)
# 0.7280168
# condition  198 / 960 : (6, 0, 0, 2, 1)
# 0.64923567
# condition  199 / 960 : (6, 0, 0, 3, 0)
# 0.80883634
# condition  200 / 960 : (6, 0, 0, 3, 1)
# 0.86305445
# condition  201 / 960 : (6, 0, 1, 0, 0)
# -0.86547315
# condition  202 / 960 : (6, 0, 1, 0, 1)
# -0.8296962
# condition  203 / 960 : (6, 0, 1, 1, 0)
# -0.79580253
# condition  204 / 960 : (6, 0, 1, 1, 1)
# -0.7261614
# condition  205 / 960 : (6, 0, 1, 2, 0)
# 0.7031932
# condition  206 / 960 : (6, 0, 1, 2, 1)
# 0.6312744
# condition  207 / 960 : (6, 0, 1, 3, 0)
# 0.83662385
# condition  208 / 960 : (6, 0, 1, 3, 1)
# 0.85327417
# condition  209 / 960 : (6, 1, 0, 0, 0)
# -0.87981325
# condition  210 / 960 : (6, 1, 0, 0, 1)
# -0.8750493
# condition  211 / 960 : (6, 1, 0, 1, 0)
# -0.84718955
# condition  212 / 960 : (6, 1, 0, 1, 1)
# -0.8153507
# condition  213 / 960 : (6, 1, 0, 2, 0)
# 0.78081834
# condition  214 / 960 : (6, 1, 0, 2, 1)
# 0.7595228
# condition  215 / 960 : (6, 1, 0, 3, 0)
# 0.85684645
# condition  216 / 960 : (6, 1, 0, 3, 1)
# 0.8851473
# condition  217 / 960 : (6, 1, 1, 0, 0)
# -0.8868342
# condition  218 / 960 : (6, 1, 1, 0, 1)
# -0.8561334
# condition  219 / 960 : (6, 1, 1, 1, 0)
# -0.8287386
# condition  220 / 960 : (6, 1, 1, 1, 1)
# -0.82160246
# condition  221 / 960 : (6, 1, 1, 2, 0)
# 0.7639226
# condition  222 / 960 : (6, 1, 1, 2, 1)
# 0.73886645
# condition  223 / 960 : (6, 1, 1, 3, 0)
# 0.8686801
# condition  224 / 960 : (6, 1, 1, 3, 1)
# 0.84922194
# condition  225 / 960 : (7, 0, 0, 0, 0)
# -0.75423515
# condition  226 / 960 : (7, 0, 0, 0, 1)
# -0.8377317
# condition  227 / 960 : (7, 0, 0, 1, 0)
# -0.573029
# condition  228 / 960 : (7, 0, 0, 1, 1)
# -0.6458773
# condition  229 / 960 : (7, 0, 0, 2, 0)
# 0.679066
# condition  230 / 960 : (7, 0, 0, 2, 1)
# 0.6448387
# condition  231 / 960 : (7, 0, 0, 3, 0)
# 0.8215589
# condition  232 / 960 : (7, 0, 0, 3, 1)
# 0.83607846
# condition  233 / 960 : (7, 0, 1, 0, 0)
# -0.7817325
# condition  234 / 960 : (7, 0, 1, 0, 1)
# -0.8642722
# condition  235 / 960 : (7, 0, 1, 1, 0)
# -0.63398767
# condition  236 / 960 : (7, 0, 1, 1, 1)
# -0.6386669
# condition  237 / 960 : (7, 0, 1, 2, 0)
# 0.7067083
# condition  238 / 960 : (7, 0, 1, 2, 1)
# 0.6918303
# condition  239 / 960 : (7, 0, 1, 3, 0)
# 0.84394574
# condition  240 / 960 : (7, 0, 1, 3, 1)
# 0.8694104
# condition  241 / 960 : (7, 1, 0, 0, 0)
# -0.82026505
# condition  242 / 960 : (7, 1, 0, 0, 1)
# -0.86445814
# condition  243 / 960 : (7, 1, 0, 1, 0)
# -0.6801565
# condition  244 / 960 : (7, 1, 0, 1, 1)
# -0.71508634
# condition  245 / 960 : (7, 1, 0, 2, 0)
# 0.7877579
# condition  246 / 960 : (7, 1, 0, 2, 1)
# 0.7897409
# condition  247 / 960 : (7, 1, 0, 3, 0)
# 0.859815
# condition  248 / 960 : (7, 1, 0, 3, 1)
# 0.8355201
# condition  249 / 960 : (7, 1, 1, 0, 0)
# -0.8122722
# condition  250 / 960 : (7, 1, 1, 0, 1)
# -0.8684475
# condition  251 / 960 : (7, 1, 1, 1, 0)
# -0.65760237
# condition  252 / 960 : (7, 1, 1, 1, 1)
# -0.7439031
# condition  253 / 960 : (7, 1, 1, 2, 0)
# 0.7612817
# condition  254 / 960 : (7, 1, 1, 2, 1)
# 0.74899507
# condition  255 / 960 : (7, 1, 1, 3, 0)
# 0.8756267
# condition  256 / 960 : (7, 1, 1, 3, 1)
# 0.86989546
# condition  257 / 960 : (8, 0, 0, 0, 0)
# -0.8510094
# condition  258 / 960 : (8, 0, 0, 0, 1)
# -0.8940097
# condition  259 / 960 : (8, 0, 0, 1, 0)
# -0.7229037
# condition  260 / 960 : (8, 0, 0, 1, 1)
# -0.72025484
# condition  261 / 960 : (8, 0, 0, 2, 0)
# 0.6871167
# condition  262 / 960 : (8, 0, 0, 2, 1)
# 0.5401917
# condition  263 / 960 : (8, 0, 0, 3, 0)
# 0.8706344
# condition  264 / 960 : (8, 0, 0, 3, 1)
# 0.8071725
# condition  265 / 960 : (8, 0, 1, 0, 0)
# -0.82036287
# condition  266 / 960 : (8, 0, 1, 0, 1)
# -0.84708166
# condition  267 / 960 : (8, 0, 1, 1, 0)
# -0.7125313
# condition  268 / 960 : (8, 0, 1, 1, 1)
# -0.7367545
# condition  269 / 960 : (8, 0, 1, 2, 0)
# 0.74139595
# condition  270 / 960 : (8, 0, 1, 2, 1)
# 0.6196287
# condition  271 / 960 : (8, 0, 1, 3, 0)
# 0.87066996
# condition  272 / 960 : (8, 0, 1, 3, 1)
# 0.8370982
# condition  273 / 960 : (8, 1, 0, 0, 0)
# -0.85624754
# condition  274 / 960 : (8, 1, 0, 0, 1)
# -0.89171845
# condition  275 / 960 : (8, 1, 0, 1, 0)
# -0.7859206
# condition  276 / 960 : (8, 1, 0, 1, 1)
# -0.74786484
# condition  277 / 960 : (8, 1, 0, 2, 0)
# 0.7764453
# condition  278 / 960 : (8, 1, 0, 2, 1)
# 0.69448173
# condition  279 / 960 : (8, 1, 0, 3, 0)
# 0.89382505
# condition  280 / 960 : (8, 1, 0, 3, 1)
# 0.87367034
# condition  281 / 960 : (8, 1, 1, 0, 0)
# -0.8237202
# condition  282 / 960 : (8, 1, 1, 0, 1)
# -0.8644139
# condition  283 / 960 : (8, 1, 1, 1, 0)
# -0.78212285
# condition  284 / 960 : (8, 1, 1, 1, 1)
# -0.74527085
# condition  285 / 960 : (8, 1, 1, 2, 0)
# 0.7666008
# condition  286 / 960 : (8, 1, 1, 2, 1)
# 0.6681282
# condition  287 / 960 : (8, 1, 1, 3, 0)
# 0.87398225
# condition  288 / 960 : (8, 1, 1, 3, 1)
# 0.8855948
# condition  289 / 960 : (9, 0, 0, 0, 0)
# -0.9263034
# condition  290 / 960 : (9, 0, 0, 0, 1)
# -0.88141763
# condition  291 / 960 : (9, 0, 0, 1, 0)
# -0.8312444
# condition  292 / 960 : (9, 0, 0, 1, 1)
# -0.64217776
# condition  293 / 960 : (9, 0, 0, 2, 0)
# 0.16487923
# condition  294 / 960 : (9, 0, 0, 2, 1)
# 0.7609012
# condition  295 / 960 : (9, 0, 0, 3, 0)
# 0.67260736
# condition  296 / 960 : (9, 0, 0, 3, 1)
# 0.87730235
# condition  297 / 960 : (9, 0, 1, 0, 0)
# -0.9087322
# condition  298 / 960 : (9, 0, 1, 0, 1)
# -0.89422625
# condition  299 / 960 : (9, 0, 1, 1, 0)
# -0.78776
# condition  300 / 960 : (9, 0, 1, 1, 1)
# -0.70082873
# condition  301 / 960 : (9, 0, 1, 2, 0)
# 0.053023137
# condition  302 / 960 : (9, 0, 1, 2, 1)
# 0.75184286
# condition  303 / 960 : (9, 0, 1, 3, 0)
# 0.6264962
# condition  304 / 960 : (9, 0, 1, 3, 1)
# 0.85510725
# condition  305 / 960 : (9, 1, 0, 0, 0)
# -0.9038737
# condition  306 / 960 : (9, 1, 0, 0, 1)
# -0.86083466
# condition  307 / 960 : (9, 1, 0, 1, 0)
# -0.83358717
# condition  308 / 960 : (9, 1, 0, 1, 1)
# -0.7665159
# condition  309 / 960 : (9, 1, 0, 2, 0)
# 0.062807076
# condition  310 / 960 : (9, 1, 0, 2, 1)
# 0.821872
# condition  311 / 960 : (9, 1, 0, 3, 0)
# 0.39705345
# condition  312 / 960 : (9, 1, 0, 3, 1)
# 0.8732017
# condition  313 / 960 : (9, 1, 1, 0, 0)
# -0.88929045
# condition  314 / 960 : (9, 1, 1, 0, 1)
# -0.87259185
# condition  315 / 960 : (9, 1, 1, 1, 0)
# -0.8385502
# condition  316 / 960 : (9, 1, 1, 1, 1)
# -0.7860265
# condition  317 / 960 : (9, 1, 1, 2, 0)
# -0.073961936
# condition  318 / 960 : (9, 1, 1, 2, 1)
# 0.8123091
# condition  319 / 960 : (9, 1, 1, 3, 0)
# 0.53886205
# condition  320 / 960 : (9, 1, 1, 3, 1)
# 0.8599287
# condition  321 / 960 : (10, 0, 0, 0, 0)
# -0.7420526
# condition  322 / 960 : (10, 0, 0, 0, 1)
# -0.85205215
# condition  323 / 960 : (10, 0, 0, 1, 0)
# -0.7811758
# condition  324 / 960 : (10, 0, 0, 1, 1)
# -0.6686502
# condition  325 / 960 : (10, 0, 0, 2, 0)
# 0.66332316
# condition  326 / 960 : (10, 0, 0, 2, 1)
# 0.70638305
# condition  327 / 960 : (10, 0, 0, 3, 0)
# 0.82112694
# condition  328 / 960 : (10, 0, 0, 3, 1)
# 0.87893295
# condition  329 / 960 : (10, 0, 1, 0, 0)
# -0.78972197
# condition  330 / 960 : (10, 0, 1, 0, 1)
# -0.8495372
# condition  331 / 960 : (10, 0, 1, 1, 0)
# -0.813942
# condition  332 / 960 : (10, 0, 1, 1, 1)
# -0.68606603
# condition  333 / 960 : (10, 0, 1, 2, 0)
# 0.6868725
# condition  334 / 960 : (10, 0, 1, 2, 1)
# 0.7093816
# condition  335 / 960 : (10, 0, 1, 3, 0)
# 0.7994472
# condition  336 / 960 : (10, 0, 1, 3, 1)
# 0.86264783
# condition  337 / 960 : (10, 1, 0, 0, 0)
# -0.8185176
# condition  338 / 960 : (10, 1, 0, 0, 1)
# -0.8885736
# condition  339 / 960 : (10, 1, 0, 1, 0)
# -0.8497063
# condition  340 / 960 : (10, 1, 0, 1, 1)
# -0.81514335
# condition  341 / 960 : (10, 1, 0, 2, 0)
# 0.8112401
# condition  342 / 960 : (10, 1, 0, 2, 1)
# 0.7708835
# condition  343 / 960 : (10, 1, 0, 3, 0)
# 0.8738463
# condition  344 / 960 : (10, 1, 0, 3, 1)
# 0.8727054
# condition  345 / 960 : (10, 1, 1, 0, 0)
# -0.8647509
# condition  346 / 960 : (10, 1, 1, 0, 1)
# -0.86375135
# condition  347 / 960 : (10, 1, 1, 1, 0)
# -0.843044
# condition  348 / 960 : (10, 1, 1, 1, 1)
# -0.7718594
# condition  349 / 960 : (10, 1, 1, 2, 0)
# 0.7802384
# condition  350 / 960 : (10, 1, 1, 2, 1)
# 0.7587959
# condition  351 / 960 : (10, 1, 1, 3, 0)
# 0.86151034
# condition  352 / 960 : (10, 1, 1, 3, 1)
# 0.8936171
# condition  353 / 960 : (11, 0, 0, 0, 0)
# -0.8709845
# condition  354 / 960 : (11, 0, 0, 0, 1)
# -0.8415746
# condition  355 / 960 : (11, 0, 0, 1, 0)
# -0.7660782
# condition  356 / 960 : (11, 0, 0, 1, 1)
# -0.73290473
# condition  357 / 960 : (11, 0, 0, 2, 0)
# 0.75323135
# condition  358 / 960 : (11, 0, 0, 2, 1)
# 0.7428366
# condition  359 / 960 : (11, 0, 0, 3, 0)
# 0.8388664
# condition  360 / 960 : (11, 0, 0, 3, 1)
# 0.8958252
# condition  361 / 960 : (11, 0, 1, 0, 0)
# -0.88434446
# condition  362 / 960 : (11, 0, 1, 0, 1)
# -0.87276566
# condition  363 / 960 : (11, 0, 1, 1, 0)
# -0.7504144
# condition  364 / 960 : (11, 0, 1, 1, 1)
# -0.72782624
# condition  365 / 960 : (11, 0, 1, 2, 0)
# 0.7079239
# condition  366 / 960 : (11, 0, 1, 2, 1)
# 0.7286925
# condition  367 / 960 : (11, 0, 1, 3, 0)
# 0.8010475
# condition  368 / 960 : (11, 0, 1, 3, 1)
# 0.82697904
# condition  369 / 960 : (11, 1, 0, 0, 0)
# -0.8944822
# condition  370 / 960 : (11, 1, 0, 0, 1)
# -0.86481875
# condition  371 / 960 : (11, 1, 0, 1, 0)
# -0.7968129
# condition  372 / 960 : (11, 1, 0, 1, 1)
# -0.79245466
# condition  373 / 960 : (11, 1, 0, 2, 0)
# 0.838799
# condition  374 / 960 : (11, 1, 0, 2, 1)
# 0.78168684
# condition  375 / 960 : (11, 1, 0, 3, 0)
# 0.8519461
# condition  376 / 960 : (11, 1, 0, 3, 1)
# 0.88570875
# condition  377 / 960 : (11, 1, 1, 0, 0)
# -0.89078337
# condition  378 / 960 : (11, 1, 1, 0, 1)
# -0.8783826
# condition  379 / 960 : (11, 1, 1, 1, 0)
# -0.813098
# condition  380 / 960 : (11, 1, 1, 1, 1)
# -0.8063851
# condition  381 / 960 : (11, 1, 1, 2, 0)
# 0.7926665
# condition  382 / 960 : (11, 1, 1, 2, 1)
# 0.7969603
# condition  383 / 960 : (11, 1, 1, 3, 0)
# 0.878269
# condition  384 / 960 : (11, 1, 1, 3, 1)
# 0.9015535
# condition  385 / 960 : (12, 0, 0, 0, 0)
# -0.9193499
# condition  386 / 960 : (12, 0, 0, 0, 1)
# -0.82625127
# condition  387 / 960 : (12, 0, 0, 1, 0)
# -0.6342863
# condition  388 / 960 : (12, 0, 0, 1, 1)
# -0.64930314
# condition  389 / 960 : (12, 0, 0, 2, 0)
# 0.5937476
# condition  390 / 960 : (12, 0, 0, 2, 1)
# 0.69790095
# condition  391 / 960 : (12, 0, 0, 3, 0)
# 0.8327493
# condition  392 / 960 : (12, 0, 0, 3, 1)
# 0.83033645
# condition  393 / 960 : (12, 0, 1, 0, 0)
# -0.8931031
# condition  394 / 960 : (12, 0, 1, 0, 1)
# -0.85849434
# condition  395 / 960 : (12, 0, 1, 1, 0)
# -0.6033343
# condition  396 / 960 : (12, 0, 1, 1, 1)
# -0.6345723
# condition  397 / 960 : (12, 0, 1, 2, 0)
# 0.6066211
# condition  398 / 960 : (12, 0, 1, 2, 1)
# 0.74379456
# condition  399 / 960 : (12, 0, 1, 3, 0)
# 0.84645706
# condition  400 / 960 : (12, 0, 1, 3, 1)
# 0.8818643
# condition  401 / 960 : (12, 1, 0, 0, 0)
# -0.88739985
# condition  402 / 960 : (12, 1, 0, 0, 1)
# -0.8732149
# condition  403 / 960 : (12, 1, 0, 1, 0)
# -0.70768565
# condition  404 / 960 : (12, 1, 0, 1, 1)
# -0.7299585
# condition  405 / 960 : (12, 1, 0, 2, 0)
# 0.7122877
# condition  406 / 960 : (12, 1, 0, 2, 1)
# 0.8269072
# condition  407 / 960 : (12, 1, 0, 3, 0)
# 0.872764
# condition  408 / 960 : (12, 1, 0, 3, 1)
# 0.8804378
# condition  409 / 960 : (12, 1, 1, 0, 0)
# -0.877585
# condition  410 / 960 : (12, 1, 1, 0, 1)
# -0.8639946
# condition  411 / 960 : (12, 1, 1, 1, 0)
# -0.70854044
# condition  412 / 960 : (12, 1, 1, 1, 1)
# -0.7382686
# condition  413 / 960 : (12, 1, 1, 2, 0)
# 0.7023395
# condition  414 / 960 : (12, 1, 1, 2, 1)
# 0.79288816
# condition  415 / 960 : (12, 1, 1, 3, 0)
# 0.85645
# condition  416 / 960 : (12, 1, 1, 3, 1)
# 0.8374384
# condition  417 / 960 : (13, 0, 0, 0, 0)
# -0.8891529
# condition  418 / 960 : (13, 0, 0, 0, 1)
# -0.87406874
# condition  419 / 960 : (13, 0, 0, 1, 0)
# -0.81330305
# condition  420 / 960 : (13, 0, 0, 1, 1)
# -0.723551
# condition  421 / 960 : (13, 0, 0, 2, 0)
# 0.6682086
# condition  422 / 960 : (13, 0, 0, 2, 1)
# 0.7832923
# condition  423 / 960 : (13, 0, 0, 3, 0)
# 0.84206027
# condition  424 / 960 : (13, 0, 0, 3, 1)
# 0.867419
# condition  425 / 960 : (13, 0, 1, 0, 0)
# -0.91984177
# condition  426 / 960 : (13, 0, 1, 0, 1)
# -0.81617063
# condition  427 / 960 : (13, 0, 1, 1, 0)
# -0.81152505
# condition  428 / 960 : (13, 0, 1, 1, 1)
# -0.6892919
# condition  429 / 960 : (13, 0, 1, 2, 0)
# 0.61423
# condition  430 / 960 : (13, 0, 1, 2, 1)
# 0.75330645
# condition  431 / 960 : (13, 0, 1, 3, 0)
# 0.83253294
# condition  432 / 960 : (13, 0, 1, 3, 1)
# 0.88355774
# condition  433 / 960 : (13, 1, 0, 0, 0)
# -0.9098061
# condition  434 / 960 : (13, 1, 0, 0, 1)
# -0.89648664
# condition  435 / 960 : (13, 1, 0, 1, 0)
# -0.8468599
# condition  436 / 960 : (13, 1, 0, 1, 1)
# -0.79673076
# condition  437 / 960 : (13, 1, 0, 2, 0)
# 0.7210358
# condition  438 / 960 : (13, 1, 0, 2, 1)
# 0.847354
# condition  439 / 960 : (13, 1, 0, 3, 0)
# 0.9195497
# condition  440 / 960 : (13, 1, 0, 3, 1)
# 0.8864176
# condition  441 / 960 : (13, 1, 1, 0, 0)
# -0.8959018
# condition  442 / 960 : (13, 1, 1, 0, 1)
# -0.867303
# condition  443 / 960 : (13, 1, 1, 1, 0)
# -0.84076875
# condition  444 / 960 : (13, 1, 1, 1, 1)
# -0.7866435
# condition  445 / 960 : (13, 1, 1, 2, 0)
# 0.7019014
# condition  446 / 960 : (13, 1, 1, 2, 1)
# 0.81236815
# condition  447 / 960 : (13, 1, 1, 3, 0)
# 0.8684344
# condition  448 / 960 : (13, 1, 1, 3, 1)
# 0.8716054
# condition  449 / 960 : (14, 0, 0, 0, 0)
# -0.81277573
# condition  450 / 960 : (14, 0, 0, 0, 1)
# -0.90412307
# condition  451 / 960 : (14, 0, 0, 1, 0)
# -0.7969896
# condition  452 / 960 : (14, 0, 0, 1, 1)
# -0.6145336
# condition  453 / 960 : (14, 0, 0, 2, 0)
# 0.7827025
# condition  454 / 960 : (14, 0, 0, 2, 1)
# 0.6703312
# condition  455 / 960 : (14, 0, 0, 3, 0)
# 0.8784886
# condition  456 / 960 : (14, 0, 0, 3, 1)
# 0.8546959
# condition  457 / 960 : (14, 0, 1, 0, 0)
# -0.7656105
# condition  458 / 960 : (14, 0, 1, 0, 1)
# -0.85501564
# condition  459 / 960 : (14, 0, 1, 1, 0)
# -0.7835513
# condition  460 / 960 : (14, 0, 1, 1, 1)
# -0.6639378
# condition  461 / 960 : (14, 0, 1, 2, 0)
# 0.7708253
# condition  462 / 960 : (14, 0, 1, 2, 1)
# 0.59972054
# condition  463 / 960 : (14, 0, 1, 3, 0)
# 0.8522118
# condition  464 / 960 : (14, 0, 1, 3, 1)
# 0.84744436
# condition  465 / 960 : (14, 1, 0, 0, 0)
# -0.83257353
# condition  466 / 960 : (14, 1, 0, 0, 1)
# -0.87009466
# condition  467 / 960 : (14, 1, 0, 1, 0)
# -0.85664314
# condition  468 / 960 : (14, 1, 0, 1, 1)
# -0.78890944
# condition  469 / 960 : (14, 1, 0, 2, 0)
# 0.83020246
# condition  470 / 960 : (14, 1, 0, 2, 1)
# 0.7616133
# condition  471 / 960 : (14, 1, 0, 3, 0)
# 0.8716393
# condition  472 / 960 : (14, 1, 0, 3, 1)
# 0.8708058
# condition  473 / 960 : (14, 1, 1, 0, 0)
# -0.845765
# condition  474 / 960 : (14, 1, 1, 0, 1)
# -0.87334776
# condition  475 / 960 : (14, 1, 1, 1, 0)
# -0.8324422
# condition  476 / 960 : (14, 1, 1, 1, 1)
# -0.7774907
# condition  477 / 960 : (14, 1, 1, 2, 0)
# 0.8212079
# condition  478 / 960 : (14, 1, 1, 2, 1)
# 0.7575318
# condition  479 / 960 : (14, 1, 1, 3, 0)
# 0.8673819
# condition  480 / 960 : (14, 1, 1, 3, 1)
# 0.8674674
# condition  481 / 960 : (15, 0, 0, 0, 0)
# -0.7058171
# condition  482 / 960 : (15, 0, 0, 0, 1)
# -0.84173965
# condition  483 / 960 : (15, 0, 0, 1, 0)
# -0.7664297
# condition  484 / 960 : (15, 0, 0, 1, 1)
# -0.6759875
# condition  485 / 960 : (15, 0, 0, 2, 0)
# 0.8354378
# condition  486 / 960 : (15, 0, 0, 2, 1)
# 0.7167742
# condition  487 / 960 : (15, 0, 0, 3, 0)
# 0.8473532
# condition  488 / 960 : (15, 0, 0, 3, 1)
# 0.87963873
# condition  489 / 960 : (15, 0, 1, 0, 0)
# -0.6863901
# condition  490 / 960 : (15, 0, 1, 0, 1)
# -0.85824126
# condition  491 / 960 : (15, 0, 1, 1, 0)
# -0.7739208
# condition  492 / 960 : (15, 0, 1, 1, 1)
# -0.66022474
# condition  493 / 960 : (15, 0, 1, 2, 0)
# 0.80443597
# condition  494 / 960 : (15, 0, 1, 2, 1)
# 0.7586626
# condition  495 / 960 : (15, 0, 1, 3, 0)
# 0.86431533
# condition  496 / 960 : (15, 0, 1, 3, 1)
# 0.83619475
# condition  497 / 960 : (15, 1, 0, 0, 0)
# -0.5481068
# condition  498 / 960 : (15, 1, 0, 0, 1)
# -0.8557016
# condition  499 / 960 : (15, 1, 0, 1, 0)
# -0.8460182
# condition  500 / 960 : (15, 1, 0, 1, 1)
# -0.7665446
# condition  501 / 960 : (15, 1, 0, 2, 0)
# 0.8724199
# condition  502 / 960 : (15, 1, 0, 2, 1)
# 0.81184906
# condition  503 / 960 : (15, 1, 0, 3, 0)
# 0.89460635
# condition  504 / 960 : (15, 1, 0, 3, 1)
# 0.8741802
# condition  505 / 960 : (15, 1, 1, 0, 0)
# -0.7602367
# condition  506 / 960 : (15, 1, 1, 0, 1)
# -0.88448244
# condition  507 / 960 : (15, 1, 1, 1, 0)
# -0.8284425
# condition  508 / 960 : (15, 1, 1, 1, 1)
# -0.7504235
# condition  509 / 960 : (15, 1, 1, 2, 0)
# 0.83754027
# condition  510 / 960 : (15, 1, 1, 2, 1)
# 0.7757053
# condition  511 / 960 : (15, 1, 1, 3, 0)
# 0.8713856
# condition  512 / 960 : (15, 1, 1, 3, 1)
# 0.86192656
# condition  513 / 960 : (16, 0, 0, 0, 0)
# -0.83586884
# condition  514 / 960 : (16, 0, 0, 0, 1)
# -0.82996213
# condition  515 / 960 : (16, 0, 0, 1, 0)
# -0.015898246
# condition  516 / 960 : (16, 0, 0, 1, 1)
# -0.7543433
# condition  517 / 960 : (16, 0, 0, 2, 0)
# 0.7836999
# condition  518 / 960 : (16, 0, 0, 2, 1)
# 0.73660016
# condition  519 / 960 : (16, 0, 0, 3, 0)
# 0.897074
# condition  520 / 960 : (16, 0, 0, 3, 1)
# 0.8441729
# condition  521 / 960 : (16, 0, 1, 0, 0)
# -0.863806
# condition  522 / 960 : (16, 0, 1, 0, 1)
# -0.88264143
# condition  523 / 960 : (16, 0, 1, 1, 0)
# -0.16835636
# condition  524 / 960 : (16, 0, 1, 1, 1)
# -0.74594826
# condition  525 / 960 : (16, 0, 1, 2, 0)
# 0.78573203
# condition  526 / 960 : (16, 0, 1, 2, 1)
# 0.69744813
# condition  527 / 960 : (16, 0, 1, 3, 0)
# 0.884146
# condition  528 / 960 : (16, 0, 1, 3, 1)
# 0.8467055
# condition  529 / 960 : (16, 1, 0, 0, 0)
# -0.86988014
# condition  530 / 960 : (16, 1, 0, 0, 1)
# -0.8524337
# condition  531 / 960 : (16, 1, 0, 1, 0)
# 0.18421209
# condition  532 / 960 : (16, 1, 0, 1, 1)
# -0.80083793
# condition  533 / 960 : (16, 1, 0, 2, 0)
# 0.8173146
# condition  534 / 960 : (16, 1, 0, 2, 1)
# 0.7926631
# condition  535 / 960 : (16, 1, 0, 3, 0)
# 0.9058687
# condition  536 / 960 : (16, 1, 0, 3, 1)
# 0.87711084
# condition  537 / 960 : (16, 1, 1, 0, 0)
# -0.8634587
# condition  538 / 960 : (16, 1, 1, 0, 1)
# -0.86030096
# condition  539 / 960 : (16, 1, 1, 1, 0)
# 0.14959306
# condition  540 / 960 : (16, 1, 1, 1, 1)
# -0.7981231
# condition  541 / 960 : (16, 1, 1, 2, 0)
# 0.8179529
# condition  542 / 960 : (16, 1, 1, 2, 1)
# 0.7816437
# condition  543 / 960 : (16, 1, 1, 3, 0)
# 0.90131104
# condition  544 / 960 : (16, 1, 1, 3, 1)
# 0.8915797
# condition  545 / 960 : (17, 0, 0, 0, 0)
# -0.8145209
# condition  546 / 960 : (17, 0, 0, 0, 1)
# -0.7754178
# condition  547 / 960 : (17, 0, 0, 1, 0)
# -0.7545066
# condition  548 / 960 : (17, 0, 0, 1, 1)
# -0.73502016
# condition  549 / 960 : (17, 0, 0, 2, 0)
# 0.248728
# condition  550 / 960 : (17, 0, 0, 2, 1)
# 0.70653963
# condition  551 / 960 : (17, 0, 0, 3, 0)
# 0.80607957
# condition  552 / 960 : (17, 0, 0, 3, 1)
# 0.8640728
# condition  553 / 960 : (17, 0, 1, 0, 0)
# -1.0641243
# condition  554 / 960 : (17, 0, 1, 0, 1)
# -0.8265999
# condition  555 / 960 : (17, 0, 1, 1, 0)
# -0.7085197
# condition  556 / 960 : (17, 0, 1, 1, 1)
# -0.69280607
# condition  557 / 960 : (17, 0, 1, 2, 0)
# 0.12980251
# condition  558 / 960 : (17, 0, 1, 2, 1)
# 0.6782463
# condition  559 / 960 : (17, 0, 1, 3, 0)
# 0.81083053
# condition  560 / 960 : (17, 0, 1, 3, 1)
# 0.8554083
# condition  561 / 960 : (17, 1, 0, 0, 0)
# -1.0670037
# condition  562 / 960 : (17, 1, 0, 0, 1)
# -0.85577637
# condition  563 / 960 : (17, 1, 0, 1, 0)
# -0.81959015
# condition  564 / 960 : (17, 1, 0, 1, 1)
# -0.79052246
# condition  565 / 960 : (17, 1, 0, 2, 0)
# 0.07371861
# condition  566 / 960 : (17, 1, 0, 2, 1)
# 0.7826694
# condition  567 / 960 : (17, 1, 0, 3, 0)
# 0.8338681
# condition  568 / 960 : (17, 1, 0, 3, 1)
# 0.85341644
# condition  569 / 960 : (17, 1, 1, 0, 0)
# -0.98388886
# condition  570 / 960 : (17, 1, 1, 0, 1)
# -0.8738495
# condition  571 / 960 : (17, 1, 1, 1, 0)
# -0.80174583
# condition  572 / 960 : (17, 1, 1, 1, 1)
# -0.75683385
# condition  573 / 960 : (17, 1, 1, 2, 0)
# 0.1250227
# condition  574 / 960 : (17, 1, 1, 2, 1)
# 0.7495072
# condition  575 / 960 : (17, 1, 1, 3, 0)
# 0.86160177
# condition  576 / 960 : (17, 1, 1, 3, 1)
# 0.85706604
# condition  577 / 960 : (18, 0, 0, 0, 0)
# -0.97655195
# condition  578 / 960 : (18, 0, 0, 0, 1)
# -0.86930865
# condition  579 / 960 : (18, 0, 0, 1, 0)
# -0.7287735
# condition  580 / 960 : (18, 0, 0, 1, 1)
# -0.7053686
# condition  581 / 960 : (18, 0, 0, 2, 0)
# -0.0046417452
# condition  582 / 960 : (18, 0, 0, 2, 1)
# 0.6890962
# condition  583 / 960 : (18, 0, 0, 3, 0)
# 0.8751433
# condition  584 / 960 : (18, 0, 0, 3, 1)
# 0.868655
# condition  585 / 960 : (18, 0, 1, 0, 0)
# -0.94155884
# condition  586 / 960 : (18, 0, 1, 0, 1)
# -0.86129045
# condition  587 / 960 : (18, 0, 1, 1, 0)
# -0.6301326
# condition  588 / 960 : (18, 0, 1, 1, 1)
# -0.70982164
# condition  589 / 960 : (18, 0, 1, 2, 0)
# 0.15156297
# condition  590 / 960 : (18, 0, 1, 2, 1)
# 0.7243674
# condition  591 / 960 : (18, 0, 1, 3, 0)
# 0.80298173
# condition  592 / 960 : (18, 0, 1, 3, 1)
# 0.8319513
# condition  593 / 960 : (18, 1, 0, 0, 0)
# -0.9334973
# condition  594 / 960 : (18, 1, 0, 0, 1)
# -0.8491695
# condition  595 / 960 : (18, 1, 0, 1, 0)
# -0.6962136
# condition  596 / 960 : (18, 1, 0, 1, 1)
# -0.80693877
# condition  597 / 960 : (18, 1, 0, 2, 0)
# 0.18250933
# condition  598 / 960 : (18, 1, 0, 2, 1)
# 0.7227481
# condition  599 / 960 : (18, 1, 0, 3, 0)
# 0.84452176
# condition  600 / 960 : (18, 1, 0, 3, 1)
# 0.8559595
# condition  601 / 960 : (18, 1, 1, 0, 0)
# -0.97992724
# condition  602 / 960 : (18, 1, 1, 0, 1)
# -0.86005706
# condition  603 / 960 : (18, 1, 1, 1, 0)
# -0.70489
# condition  604 / 960 : (18, 1, 1, 1, 1)
# -0.8169484
# condition  605 / 960 : (18, 1, 1, 2, 0)
# -0.0043046116
# condition  606 / 960 : (18, 1, 1, 2, 1)
# 0.7251098
# condition  607 / 960 : (18, 1, 1, 3, 0)
# 0.8500543
# condition  608 / 960 : (18, 1, 1, 3, 1)
# 0.8426179
# condition  609 / 960 : (19, 0, 0, 0, 0)
# -0.8777991
# condition  610 / 960 : (19, 0, 0, 0, 1)
# -0.85072184
# condition  611 / 960 : (19, 0, 0, 1, 0)
# -0.83974093
# condition  612 / 960 : (19, 0, 0, 1, 1)
# -0.744635
# condition  613 / 960 : (19, 0, 0, 2, 0)
# 0.7092819
# condition  614 / 960 : (19, 0, 0, 2, 1)
# 0.6659857
# condition  615 / 960 : (19, 0, 0, 3, 0)
# 0.741548
# condition  616 / 960 : (19, 0, 0, 3, 1)
# 0.8544639
# condition  617 / 960 : (19, 0, 1, 0, 0)
# -0.8711539
# condition  618 / 960 : (19, 0, 1, 0, 1)
# -0.8669181
# condition  619 / 960 : (19, 0, 1, 1, 0)
# -0.7942955
# condition  620 / 960 : (19, 0, 1, 1, 1)
# -0.7081522
# condition  621 / 960 : (19, 0, 1, 2, 0)
# 0.7446633
# condition  622 / 960 : (19, 0, 1, 2, 1)
# 0.6946583
# condition  623 / 960 : (19, 0, 1, 3, 0)
# 0.7593556
# condition  624 / 960 : (19, 0, 1, 3, 1)
# 0.80227643
# condition  625 / 960 : (19, 1, 0, 0, 0)
# -0.868455
# condition  626 / 960 : (19, 1, 0, 0, 1)
# -0.8690038
# condition  627 / 960 : (19, 1, 0, 1, 0)
# -0.8675276
# condition  628 / 960 : (19, 1, 0, 1, 1)
# -0.81945765
# condition  629 / 960 : (19, 1, 0, 2, 0)
# 0.7931905
# condition  630 / 960 : (19, 1, 0, 2, 1)
# 0.80492705
# condition  631 / 960 : (19, 1, 0, 3, 0)
# 0.8034946
# condition  632 / 960 : (19, 1, 0, 3, 1)
# 0.84559476
# condition  633 / 960 : (19, 1, 1, 0, 0)
# -0.86822504
# condition  634 / 960 : (19, 1, 1, 0, 1)
# -0.8708212
# condition  635 / 960 : (19, 1, 1, 1, 0)
# -0.8535106
# condition  636 / 960 : (19, 1, 1, 1, 1)
# -0.79420036
# condition  637 / 960 : (19, 1, 1, 2, 0)
# 0.78991926
# condition  638 / 960 : (19, 1, 1, 2, 1)
# 0.75554776
# condition  639 / 960 : (19, 1, 1, 3, 0)
# 0.7920793
# condition  640 / 960 : (19, 1, 1, 3, 1)
# 0.8707215
# condition  641 / 960 : (20, 0, 0, 0, 0)
# -0.8789536
# condition  642 / 960 : (20, 0, 0, 0, 1)
# -0.85479754
# condition  643 / 960 : (20, 0, 0, 1, 0)
# -0.7777521
# condition  644 / 960 : (20, 0, 0, 1, 1)
# -0.6853643
# condition  645 / 960 : (20, 0, 0, 2, 0)
# 0.76494604
# condition  646 / 960 : (20, 0, 0, 2, 1)
# 0.66131663
# condition  647 / 960 : (20, 0, 0, 3, 0)
# 0.82704085
# condition  648 / 960 : (20, 0, 0, 3, 1)
# 0.8692795
# condition  649 / 960 : (20, 0, 1, 0, 0)
# -0.8832883
# condition  650 / 960 : (20, 0, 1, 0, 1)
# -0.88467896
# condition  651 / 960 : (20, 0, 1, 1, 0)
# -0.75654894
# condition  652 / 960 : (20, 0, 1, 1, 1)
# -0.71603286
# condition  653 / 960 : (20, 0, 1, 2, 0)
# 0.68286496
# condition  654 / 960 : (20, 0, 1, 2, 1)
# 0.65509385
# condition  655 / 960 : (20, 0, 1, 3, 0)
# 0.8057194
# condition  656 / 960 : (20, 0, 1, 3, 1)
# 0.8536486
# condition  657 / 960 : (20, 1, 0, 0, 0)
# -0.86879426
# condition  658 / 960 : (20, 1, 0, 0, 1)
# -0.8819588
# condition  659 / 960 : (20, 1, 0, 1, 0)
# -0.8229879
# condition  660 / 960 : (20, 1, 0, 1, 1)
# -0.7965714
# condition  661 / 960 : (20, 1, 0, 2, 0)
# 0.7997336
# condition  662 / 960 : (20, 1, 0, 2, 1)
# 0.8133316
# condition  663 / 960 : (20, 1, 0, 3, 0)
# 0.8419437
# condition  664 / 960 : (20, 1, 0, 3, 1)
# 0.8563511
# condition  665 / 960 : (20, 1, 1, 0, 0)
# -0.8523093
# condition  666 / 960 : (20, 1, 1, 0, 1)
# -0.8590842
# condition  667 / 960 : (20, 1, 1, 1, 0)
# -0.81579053
# condition  668 / 960 : (20, 1, 1, 1, 1)
# -0.7590703
# condition  669 / 960 : (20, 1, 1, 2, 0)
# 0.7965216
# condition  670 / 960 : (20, 1, 1, 2, 1)
# 0.76389265
# condition  671 / 960 : (20, 1, 1, 3, 0)
# 0.84234756
# condition  672 / 960 : (20, 1, 1, 3, 1)
# 0.86630577
# condition  673 / 960 : (21, 0, 0, 0, 0)
# -0.8437557
# condition  674 / 960 : (21, 0, 0, 0, 1)
# -0.86652493
# condition  675 / 960 : (21, 0, 0, 1, 0)
# -0.72642624
# condition  676 / 960 : (21, 0, 0, 1, 1)
# -0.7433162
# condition  677 / 960 : (21, 0, 0, 2, 0)
# 0.77985156
# condition  678 / 960 : (21, 0, 0, 2, 1)
# 0.69846827
# condition  679 / 960 : (21, 0, 0, 3, 0)
# 0.38633397
# condition  680 / 960 : (21, 0, 0, 3, 1)
# 0.8574472
# condition  681 / 960 : (21, 0, 1, 0, 0)
# -0.85207933
# condition  682 / 960 : (21, 0, 1, 0, 1)
# -0.8377842
# condition  683 / 960 : (21, 0, 1, 1, 0)
# -0.7316466
# condition  684 / 960 : (21, 0, 1, 1, 1)
# -0.6886386
# condition  685 / 960 : (21, 0, 1, 2, 0)
# 0.7649139
# condition  686 / 960 : (21, 0, 1, 2, 1)
# 0.7054067
# condition  687 / 960 : (21, 0, 1, 3, 0)
# 0.36637938
# condition  688 / 960 : (21, 0, 1, 3, 1)
# 0.83143204
# condition  689 / 960 : (21, 1, 0, 0, 0)
# -0.8939549
# condition  690 / 960 : (21, 1, 0, 0, 1)
# -0.8645085
# condition  691 / 960 : (21, 1, 0, 1, 0)
# -0.794215
# condition  692 / 960 : (21, 1, 0, 1, 1)
# -0.7906966
# condition  693 / 960 : (21, 1, 0, 2, 0)
# 0.83722275
# condition  694 / 960 : (21, 1, 0, 2, 1)
# 0.81017625
# condition  695 / 960 : (21, 1, 0, 3, 0)
# 0.38957202
# condition  696 / 960 : (21, 1, 0, 3, 1)
# 0.8642537
# condition  697 / 960 : (21, 1, 1, 0, 0)
# -0.8759466
# condition  698 / 960 : (21, 1, 1, 0, 1)
# -0.87962157
# condition  699 / 960 : (21, 1, 1, 1, 0)
# -0.7754233
# condition  700 / 960 : (21, 1, 1, 1, 1)
# -0.76044303
# condition  701 / 960 : (21, 1, 1, 2, 0)
# 0.7870917
# condition  702 / 960 : (21, 1, 1, 2, 1)
# 0.7639214
# condition  703 / 960 : (21, 1, 1, 3, 0)
# 0.67990386
# condition  704 / 960 : (21, 1, 1, 3, 1)
# 0.8558916
# condition  705 / 960 : (22, 0, 0, 0, 0)
# -0.77486503
# condition  706 / 960 : (22, 0, 0, 0, 1)
# -0.83505404
# condition  707 / 960 : (22, 0, 0, 1, 0)
# -0.0119581865
# condition  708 / 960 : (22, 0, 0, 1, 1)
# -0.73291886
# condition  709 / 960 : (22, 0, 0, 2, 0)
# 0.74227095
# condition  710 / 960 : (22, 0, 0, 2, 1)
# 0.74338776
# condition  711 / 960 : (22, 0, 0, 3, 0)
# 0.93156415
# condition  712 / 960 : (22, 0, 0, 3, 1)
# 0.9065495
# condition  713 / 960 : (22, 0, 1, 0, 0)
# -0.7874443
# condition  714 / 960 : (22, 0, 1, 0, 1)
# -0.87049943
# condition  715 / 960 : (22, 0, 1, 1, 0)
# 0.10097496
# condition  716 / 960 : (22, 0, 1, 1, 1)
# -0.72769254
# condition  717 / 960 : (22, 0, 1, 2, 0)
# 0.75488544
# condition  718 / 960 : (22, 0, 1, 2, 1)
# 0.7434309
# condition  719 / 960 : (22, 0, 1, 3, 0)
# 0.90559936
# condition  720 / 960 : (22, 0, 1, 3, 1)
# 0.867827
# condition  721 / 960 : (22, 1, 0, 0, 0)
# -0.8391261
# condition  722 / 960 : (22, 1, 0, 0, 1)
# -0.8678888
# condition  723 / 960 : (22, 1, 0, 1, 0)
# 0.26267812
# condition  724 / 960 : (22, 1, 0, 1, 1)
# -0.82006615
# condition  725 / 960 : (22, 1, 0, 2, 0)
# 0.7765288
# condition  726 / 960 : (22, 1, 0, 2, 1)
# 0.7935121
# condition  727 / 960 : (22, 1, 0, 3, 0)
# 0.905345
# condition  728 / 960 : (22, 1, 0, 3, 1)
# 0.8633241
# condition  729 / 960 : (22, 1, 1, 0, 0)
# -0.84360856
# condition  730 / 960 : (22, 1, 1, 0, 1)
# -0.8568214
# condition  731 / 960 : (22, 1, 1, 1, 0)
# 0.1133634
# condition  732 / 960 : (22, 1, 1, 1, 1)
# -0.81263715
# condition  733 / 960 : (22, 1, 1, 2, 0)
# 0.81890184
# condition  734 / 960 : (22, 1, 1, 2, 1)
# 0.8172519
# condition  735 / 960 : (22, 1, 1, 3, 0)
# 0.90247464
# condition  736 / 960 : (22, 1, 1, 3, 1)
# 0.86369216
# condition  737 / 960 : (23, 0, 0, 0, 0)
# -0.8713188
# condition  738 / 960 : (23, 0, 0, 0, 1)
# -0.8355348
# condition  739 / 960 : (23, 0, 0, 1, 0)
# -0.74437255
# condition  740 / 960 : (23, 0, 0, 1, 1)
# -0.6632301
# condition  741 / 960 : (23, 0, 0, 2, 0)
# 0.7425627
# condition  742 / 960 : (23, 0, 0, 2, 1)
# 0.7105443
# condition  743 / 960 : (23, 0, 0, 3, 0)
# 0.8046085
# condition  744 / 960 : (23, 0, 0, 3, 1)
# 0.85734487
# condition  745 / 960 : (23, 0, 1, 0, 0)
# -0.86331946
# condition  746 / 960 : (23, 0, 1, 0, 1)
# -0.84196806
# condition  747 / 960 : (23, 0, 1, 1, 0)
# -0.7173132
# condition  748 / 960 : (23, 0, 1, 1, 1)
# -0.7463884
# condition  749 / 960 : (23, 0, 1, 2, 0)
# 0.69688416
# condition  750 / 960 : (23, 0, 1, 2, 1)
# 0.7126773
# condition  751 / 960 : (23, 0, 1, 3, 0)
# 0.699416
# condition  752 / 960 : (23, 0, 1, 3, 1)
# 0.8773077
# condition  753 / 960 : (23, 1, 0, 0, 0)
# -0.8687946
# condition  754 / 960 : (23, 1, 0, 0, 1)
# -0.882606
# condition  755 / 960 : (23, 1, 0, 1, 0)
# -0.7799255
# condition  756 / 960 : (23, 1, 0, 1, 1)
# -0.79471743
# condition  757 / 960 : (23, 1, 0, 2, 0)
# 0.7691388
# condition  758 / 960 : (23, 1, 0, 2, 1)
# 0.79807615
# condition  759 / 960 : (23, 1, 0, 3, 0)
# 0.76268524
# condition  760 / 960 : (23, 1, 0, 3, 1)
# 0.8503334
# condition  761 / 960 : (23, 1, 1, 0, 0)
# -0.8892134
# condition  762 / 960 : (23, 1, 1, 0, 1)
# -0.8896004
# condition  763 / 960 : (23, 1, 1, 1, 0)
# -0.76887727
# condition  764 / 960 : (23, 1, 1, 1, 1)
# -0.77299637
# condition  765 / 960 : (23, 1, 1, 2, 0)
# 0.77419055
# condition  766 / 960 : (23, 1, 1, 2, 1)
# 0.782208
# condition  767 / 960 : (23, 1, 1, 3, 0)
# 0.74896926
# condition  768 / 960 : (23, 1, 1, 3, 1)
# 0.8706114
# condition  769 / 960 : (24, 0, 0, 0, 0)
# -1.0310036
# condition  770 / 960 : (24, 0, 0, 0, 1)
# -0.8270503
# condition  771 / 960 : (24, 0, 0, 1, 0)
# -0.77165896
# condition  772 / 960 : (24, 0, 0, 1, 1)
# -0.74024945
# condition  773 / 960 : (24, 0, 0, 2, 0)
# 0.6042194
# condition  774 / 960 : (24, 0, 0, 2, 1)
# 0.7875914
# condition  775 / 960 : (24, 0, 0, 3, 0)
# 0.8586867
# condition  776 / 960 : (24, 0, 0, 3, 1)
# 0.89222914
# condition  777 / 960 : (24, 0, 1, 0, 0)
# -0.925246
# condition  778 / 960 : (24, 0, 1, 0, 1)
# -0.87609786
# condition  779 / 960 : (24, 0, 1, 1, 0)
# -0.72883695
# condition  780 / 960 : (24, 0, 1, 1, 1)
# -0.73234224
# condition  781 / 960 : (24, 0, 1, 2, 0)
# 0.54863745
# condition  782 / 960 : (24, 0, 1, 2, 1)
# 0.7752394
# condition  783 / 960 : (24, 0, 1, 3, 0)
# 0.8543515
# condition  784 / 960 : (24, 0, 1, 3, 1)
# 0.8222929
# condition  785 / 960 : (24, 1, 0, 0, 0)
# -0.86959517
# condition  786 / 960 : (24, 1, 0, 0, 1)
# -0.8954763
# condition  787 / 960 : (24, 1, 0, 1, 0)
# -0.8084845
# condition  788 / 960 : (24, 1, 0, 1, 1)
# -0.7955044
# condition  789 / 960 : (24, 1, 0, 2, 0)
# 0.73044914
# condition  790 / 960 : (24, 1, 0, 2, 1)
# 0.8136638
# condition  791 / 960 : (24, 1, 0, 3, 0)
# 0.84549934
# condition  792 / 960 : (24, 1, 0, 3, 1)
# 0.8543341
# condition  793 / 960 : (24, 1, 1, 0, 0)
# -0.89222914
# condition  794 / 960 : (24, 1, 1, 0, 1)
# -0.8861878
# condition  795 / 960 : (24, 1, 1, 1, 0)
# -0.79384923
# condition  796 / 960 : (24, 1, 1, 1, 1)
# -0.8064728
# condition  797 / 960 : (24, 1, 1, 2, 0)
# 0.6866014
# condition  798 / 960 : (24, 1, 1, 2, 1)
# 0.8110556
# condition  799 / 960 : (24, 1, 1, 3, 0)
# 0.8573378
# condition  800 / 960 : (24, 1, 1, 3, 1)
# 0.89120454
# condition  801 / 960 : (25, 0, 0, 0, 0)
# -0.8313599
# condition  802 / 960 : (25, 0, 0, 0, 1)
# -0.8940568
# condition  803 / 960 : (25, 0, 0, 1, 0)
# -0.7149889
# condition  804 / 960 : (25, 0, 0, 1, 1)
# -0.7245889
# condition  805 / 960 : (25, 0, 0, 2, 0)
# 0.5825067
# condition  806 / 960 : (25, 0, 0, 2, 1)
# 0.7491964
# condition  807 / 960 : (25, 0, 0, 3, 0)
# 0.7613645
# condition  808 / 960 : (25, 0, 0, 3, 1)
# 0.873489
# condition  809 / 960 : (25, 0, 1, 0, 0)
# -0.7907621
# condition  810 / 960 : (25, 0, 1, 0, 1)
# -0.85005414
# condition  811 / 960 : (25, 0, 1, 1, 0)
# -0.6732898
# condition  812 / 960 : (25, 0, 1, 1, 1)
# -0.7437927
# condition  813 / 960 : (25, 0, 1, 2, 0)
# 0.5438437
# condition  814 / 960 : (25, 0, 1, 2, 1)
# 0.6930057
# condition  815 / 960 : (25, 0, 1, 3, 0)
# 0.42800263
# condition  816 / 960 : (25, 0, 1, 3, 1)
# 0.8908317
# condition  817 / 960 : (25, 1, 0, 0, 0)
# -0.8702813
# condition  818 / 960 : (25, 1, 0, 0, 1)
# -0.86452866
# condition  819 / 960 : (25, 1, 0, 1, 0)
# -0.7731693
# condition  820 / 960 : (25, 1, 0, 1, 1)
# -0.7938638
# condition  821 / 960 : (25, 1, 0, 2, 0)
# 0.7015441
# condition  822 / 960 : (25, 1, 0, 2, 1)
# 0.81173277
# condition  823 / 960 : (25, 1, 0, 3, 0)
# 0.7222922
# condition  824 / 960 : (25, 1, 0, 3, 1)
# 0.8901146
# condition  825 / 960 : (25, 1, 1, 0, 0)
# -0.9157774
# condition  826 / 960 : (25, 1, 1, 0, 1)
# -0.8808572
# condition  827 / 960 : (25, 1, 1, 1, 0)
# -0.775474
# condition  828 / 960 : (25, 1, 1, 1, 1)
# -0.801615
# condition  829 / 960 : (25, 1, 1, 2, 0)
# 0.698229
# condition  830 / 960 : (25, 1, 1, 2, 1)
# 0.8160414
# condition  831 / 960 : (25, 1, 1, 3, 0)
# 0.6264472
# condition  832 / 960 : (25, 1, 1, 3, 1)
# 0.8396416
# condition  833 / 960 : (26, 0, 0, 0, 0)
# -0.85425055
# condition  834 / 960 : (26, 0, 0, 0, 1)
# -0.8165254
# condition  835 / 960 : (26, 0, 0, 1, 0)
# -0.7210494
# condition  836 / 960 : (26, 0, 0, 1, 1)
# -0.7295947
# condition  837 / 960 : (26, 0, 0, 2, 0)
# 0.74933535
# condition  838 / 960 : (26, 0, 0, 2, 1)
# 0.6866148
# condition  839 / 960 : (26, 0, 0, 3, 0)
# 0.7512464
# condition  840 / 960 : (26, 0, 0, 3, 1)
# 0.8369583
# condition  841 / 960 : (26, 0, 1, 0, 0)
# -0.8502984
# condition  842 / 960 : (26, 0, 1, 0, 1)
# -0.80961394
# condition  843 / 960 : (26, 0, 1, 1, 0)
# -0.7194963
# condition  844 / 960 : (26, 0, 1, 1, 1)
# -0.7224745
# condition  845 / 960 : (26, 0, 1, 2, 0)
# 0.7561415
# condition  846 / 960 : (26, 0, 1, 2, 1)
# 0.69059134
# condition  847 / 960 : (26, 0, 1, 3, 0)
# 0.8362694
# condition  848 / 960 : (26, 0, 1, 3, 1)
# 0.9013521
# condition  849 / 960 : (26, 1, 0, 0, 0)
# -0.8583363
# condition  850 / 960 : (26, 1, 0, 0, 1)
# -0.88205063
# condition  851 / 960 : (26, 1, 0, 1, 0)
# -0.7995453
# condition  852 / 960 : (26, 1, 0, 1, 1)
# -0.78091276
# condition  853 / 960 : (26, 1, 0, 2, 0)
# 0.8145651
# condition  854 / 960 : (26, 1, 0, 2, 1)
# 0.7997494
# condition  855 / 960 : (26, 1, 0, 3, 0)
# 0.8414748
# condition  856 / 960 : (26, 1, 0, 3, 1)
# 0.8828209
# condition  857 / 960 : (26, 1, 1, 0, 0)
# -0.874196
# condition  858 / 960 : (26, 1, 1, 0, 1)
# -0.8363791
# condition  859 / 960 : (26, 1, 1, 1, 0)
# -0.79237866
# condition  860 / 960 : (26, 1, 1, 1, 1)
# -0.7660555
# condition  861 / 960 : (26, 1, 1, 2, 0)
# 0.8202475
# condition  862 / 960 : (26, 1, 1, 2, 1)
# 0.79999864
# condition  863 / 960 : (26, 1, 1, 3, 0)
# 0.87738144
# condition  864 / 960 : (26, 1, 1, 3, 1)
# 0.84739244
# condition  865 / 960 : (27, 0, 0, 0, 0)
# -0.7265547
# condition  866 / 960 : (27, 0, 0, 0, 1)
# -0.91033983
# condition  867 / 960 : (27, 0, 0, 1, 0)
# -0.5553311
# condition  868 / 960 : (27, 0, 0, 1, 1)
# -0.7433354
# condition  869 / 960 : (27, 0, 0, 2, 0)
# 0.7475156
# condition  870 / 960 : (27, 0, 0, 2, 1)
# 0.748191
# condition  871 / 960 : (27, 0, 0, 3, 0)
# 0.8730728
# condition  872 / 960 : (27, 0, 0, 3, 1)
# 0.83440673
# condition  873 / 960 : (27, 0, 1, 0, 0)
# -0.61426944
# condition  874 / 960 : (27, 0, 1, 0, 1)
# -0.872314
# condition  875 / 960 : (27, 0, 1, 1, 0)
# -0.5865629
# condition  876 / 960 : (27, 0, 1, 1, 1)
# -0.7565448
# condition  877 / 960 : (27, 0, 1, 2, 0)
# 0.7298496
# condition  878 / 960 : (27, 0, 1, 2, 1)
# 0.70781636
# condition  879 / 960 : (27, 0, 1, 3, 0)
# 0.86756647
# condition  880 / 960 : (27, 0, 1, 3, 1)
# 0.8949937
# condition  881 / 960 : (27, 1, 0, 0, 0)
# -0.6044427
# condition  882 / 960 : (27, 1, 0, 0, 1)
# -0.8693764
# condition  883 / 960 : (27, 1, 0, 1, 0)
# -0.6800943
# condition  884 / 960 : (27, 1, 0, 1, 1)
# -0.81440187
# condition  885 / 960 : (27, 1, 0, 2, 0)
# 0.80861825
# condition  886 / 960 : (27, 1, 0, 2, 1)
# 0.8106584
# condition  887 / 960 : (27, 1, 0, 3, 0)
# 0.8465349
# condition  888 / 960 : (27, 1, 0, 3, 1)
# 0.8681012
# condition  889 / 960 : (27, 1, 1, 0, 0)
# -0.5793125
# condition  890 / 960 : (27, 1, 1, 0, 1)
# -0.8813884
# condition  891 / 960 : (27, 1, 1, 1, 0)
# -0.6774478
# condition  892 / 960 : (27, 1, 1, 1, 1)
# -0.84090877
# condition  893 / 960 : (27, 1, 1, 2, 0)
# 0.7851007
# condition  894 / 960 : (27, 1, 1, 2, 1)
# 0.7794554
# condition  895 / 960 : (27, 1, 1, 3, 0)
# 0.8428906
# condition  896 / 960 : (27, 1, 1, 3, 1)
# 0.8669216
# condition  897 / 960 : (28, 0, 0, 0, 0)
# -0.8443852
# condition  898 / 960 : (28, 0, 0, 0, 1)
# -0.83504134
# condition  899 / 960 : (28, 0, 0, 1, 0)
# -0.5584304
# condition  900 / 960 : (28, 0, 0, 1, 1)
# -0.6690568
# condition  901 / 960 : (28, 0, 0, 2, 0)
# 0.81556517
# condition  902 / 960 : (28, 0, 0, 2, 1)
# 0.7212757
# condition  903 / 960 : (28, 0, 0, 3, 0)
# 0.7771192
# condition  904 / 960 : (28, 0, 0, 3, 1)
# 0.8254555
# condition  905 / 960 : (28, 0, 1, 0, 0)
# -0.88620406
# condition  906 / 960 : (28, 0, 1, 0, 1)
# -0.85633546
# condition  907 / 960 : (28, 0, 1, 1, 0)
# -0.5667596
# condition  908 / 960 : (28, 0, 1, 1, 1)
# -0.678636
# condition  909 / 960 : (28, 0, 1, 2, 0)
# 0.81286895
# condition  910 / 960 : (28, 0, 1, 2, 1)
# 0.68631804
# condition  911 / 960 : (28, 0, 1, 3, 0)
# 0.83654094
# condition  912 / 960 : (28, 0, 1, 3, 1)
# 0.82510984
# condition  913 / 960 : (28, 1, 0, 0, 0)
# -0.8729663
# condition  914 / 960 : (28, 1, 0, 0, 1)
# -0.8682182
# condition  915 / 960 : (28, 1, 0, 1, 0)
# -0.7495009
# condition  916 / 960 : (28, 1, 0, 1, 1)
# -0.80561966
# condition  917 / 960 : (28, 1, 0, 2, 0)
# 0.85776186
# condition  918 / 960 : (28, 1, 0, 2, 1)
# 0.797789
# condition  919 / 960 : (28, 1, 0, 3, 0)
# 0.83805937
# condition  920 / 960 : (28, 1, 0, 3, 1)
# 0.8502133
# condition  921 / 960 : (28, 1, 1, 0, 0)
# -0.87980056
# condition  922 / 960 : (28, 1, 1, 0, 1)
# -0.8704354
# condition  923 / 960 : (28, 1, 1, 1, 0)
# -0.7006845
# condition  924 / 960 : (28, 1, 1, 1, 1)
# -0.7452743
# condition  925 / 960 : (28, 1, 1, 2, 0)
# 0.84546494
# condition  926 / 960 : (28, 1, 1, 2, 1)
# 0.7932271
# condition  927 / 960 : (28, 1, 1, 3, 0)
# 0.8088278
# condition  928 / 960 : (28, 1, 1, 3, 1)
# 0.87689865
# condition  929 / 960 : (29, 0, 0, 0, 0)
# -0.84967524
# condition  930 / 960 : (29, 0, 0, 0, 1)
# -0.8477502
# condition  931 / 960 : (29, 0, 0, 1, 0)
# -0.55891967
# condition  932 / 960 : (29, 0, 0, 1, 1)
# -0.72864825
# condition  933 / 960 : (29, 0, 0, 2, 0)
# 0.81209946
# condition  934 / 960 : (29, 0, 0, 2, 1)
# 0.72597617
# condition  935 / 960 : (29, 0, 0, 3, 0)
# 0.86838204
# condition  936 / 960 : (29, 0, 0, 3, 1)
# 0.88216096
# condition  937 / 960 : (29, 0, 1, 0, 0)
# running run_seed29_nscale0.5_D192_stim2_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# No context argument was provided to nengo_ocl.Simulator
# Calling pyopencl.create_some_context() for you now:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.8104125
# -0.8104125
# condition  938 / 960 : (29, 0, 1, 0, 1)
# running run_seed29_nscale0.5_D192_stim2_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.8427159
# -0.8427159
# condition  939 / 960 : (29, 0, 1, 1, 0)
# running run_seed29_nscale0.5_D192_stim4_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.53783125
# -0.53783125
# condition  940 / 960 : (29, 0, 1, 1, 1)
# running run_seed29_nscale0.5_D192_stim4_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.74845856
# -0.74845856
# condition  941 / 960 : (29, 0, 1, 2, 0)
# running run_seed29_nscale0.5_D192_stim6_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.83765864
# 0.83765864
# condition  942 / 960 : (29, 0, 1, 2, 1)
# running run_seed29_nscale0.5_D192_stim6_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.7607557
# 0.7607557
# condition  943 / 960 : (29, 0, 1, 3, 0)
# running run_seed29_nscale0.5_D192_stim8_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.84562
# 0.84562
# condition  944 / 960 : (29, 0, 1, 3, 1)
# running run_seed29_nscale0.5_D192_stim8_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.5
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.85342234
# 0.85342234
# condition  945 / 960 : (29, 1, 0, 0, 0)
# running run_seed29_nscale1_D96_stim2_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.85996324
# -0.85996324
# condition  946 / 960 : (29, 1, 0, 0, 1)
# running run_seed29_nscale1_D96_stim2_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.8713464
# -0.8713464
# condition  947 / 960 : (29, 1, 0, 1, 0)
# running run_seed29_nscale1_D96_stim4_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.74373513
# -0.74373513
# condition  948 / 960 : (29, 1, 0, 1, 1)
# running run_seed29_nscale1_D96_stim4_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.7745225
# -0.7745225
# condition  949 / 960 : (29, 1, 0, 2, 0)
# running run_seed29_nscale1_D96_stim6_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.8432704
# 0.8432704
# condition  950 / 960 : (29, 1, 0, 2, 1)
# running run_seed29_nscale1_D96_stim6_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.78217864
# 0.78217864
# condition  951 / 960 : (29, 1, 0, 3, 0)
# running run_seed29_nscale1_D96_stim8_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.87457764
# 0.87457764
# condition  952 / 960 : (29, 1, 0, 3, 1)
# running run_seed29_nscale1_D96_stim8_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.8321043
# 0.8321043
# condition  953 / 960 : (29, 1, 1, 0, 0)
# running run_seed29_nscale1_D192_stim2_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.8707782
# -0.8707782
# condition  954 / 960 : (29, 1, 1, 0, 1)
# running run_seed29_nscale1_D192_stim2_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.857263
# -0.857263
# condition  955 / 960 : (29, 1, 1, 1, 0)
# running run_seed29_nscale1_D192_stim4_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.6712232
# -0.6712232
# condition  956 / 960 : (29, 1, 1, 1, 1)
# running run_seed29_nscale1_D192_stim4_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.8094837
# -0.8094837
# condition  957 / 960 : (29, 1, 1, 2, 0)
# running run_seed29_nscale1_D192_stim6_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.84357625
# 0.84357625
# condition  958 / 960 : (29, 1, 1, 2, 1)
# running run_seed29_nscale1_D192_stim6_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.7705901
# 0.7705901
# condition  959 / 960 : (29, 1, 1, 3, 0)
# running run_seed29_nscale1_D192_stim8_nsamples100
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.876757
# 0.876757
# condition  960 / 960 : (29, 1, 1, 3, 1)
# running run_seed29_nscale1_D192_stim8_nsamples1000
# stimuli ['D8', 'D2', 'D4', 'D3', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 29
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 1
# s_evidence = 20
# D = 192
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.83623123
# 0.83623123

# %%
# x_spacing = .2
# x_spacing_count = (-x_spacing * (len(n_neurons_scales) * len(Ds) * len(ns_samples)-1))/2
# print(x_spacing)
# linestyles = ['-','-.','--']
# colors = ['black','gray','black']
# for n_neurons_scale in range(len(n_neurons_scales)):
#     for D in range(len(Ds)):
#         for n_samples in range(len(ns_samples)):
            
#             plt.errorbar(
#                 x_spacing_count+np.array(stimuli),
#                 np.abs(np.mean(mean_comparisons[:,n_neurons_scale,D,:,n_samples], axis=(0,))),
#                 np.std(mean_comparisons[:,n_neurons_scale,D,:,n_samples], axis=(0,)),
#                 label=str(n_neurons_scales[n_neurons_scale])+' '+str(Ds[D])+' '+str(ns_samples[n_samples])+' '+str(n_neurons_scales[condition[1]]),
#                 linestyle=linestyles[n_neurons_scale],
#                 color=colors[n_samples]
#             )
            
#             x_spacing_count += x_spacing
            
# plt.xticks([2,4,6,8])
# plt.xlabel('Stimulus')
# plt.ylabel('Comparison magnitude')
    
# plt.legend()
# plt.show()

# %%
seeds = list(range(1000))
n_neurons_scales = [.25,.5,1]#,2]
Ds = [96]#,144,192]
stimuli = [2,4,6,8]
ns_samples = [100,1000,10000]

mean_comparisons = np.zeros((len(seeds), len(n_neurons_scales), len(Ds), len(stimuli), len(ns_samples)))

i=0
for condition in product(*tuple([range(len(param_values)) for param_values in [seeds, n_neurons_scales, Ds, stimuli, ns_samples]])):
    i+=1
    print('condition ', i, '/', mean_comparisons.size, ':', condition)    
    
    data_filename = 'run_seed'+str(seeds[condition[0]])+'_nscale'+str(n_neurons_scales[condition[1]])+'_D'+str(Ds[condition[2]])+'_stim'+str(stimuli[condition[3]])+'_nsamples'+str(ns_samples[condition[4]])
    
    try:
        mean_comparison = pickle.load(open(data_dir+'/'+data_filename, "rb"))
    
    except FileNotFoundError:
        try:
            mean_comparison = ExperimentRun().run(
                seed=seeds[condition[0]],
                n_neurons_scale=n_neurons_scales[condition[1]],
                D=Ds[condition[2]],
                stimulus=stimuli[condition[3]],
                n_samples=ns_samples[condition[4]],
                backend="nengo_ocl",
                data_dir=data_dir,
                data_filename=data_filename,
            )['mean_comparison']

            pickle.dump(mean_comparison, open(data_dir+'/'+data_filename, "wb"))
        
        except MemoryError:
            print('Memory error', seeds[condition[0]], n_neurons_scales[condition[1]], Ds[condition[2]], stimuli[condition[3]], ns_samples[condition[4]])
            mean_comparison = np.nan
    
    mean_comparisons[condition] = mean_comparison
    print(mean_comparison)
# Out:
# condition  1 / 36000 : (0, 0, 0, 0, 0)
# running run_seed0_nscale0.25_D96_stim2_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.8615903
# -0.8615903
# condition  2 / 36000 : (0, 0, 0, 0, 1)
# running run_seed0_nscale0.25_D96_stim2_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.8027783
# -0.8027783
# condition  3 / 36000 : (0, 0, 0, 0, 2)
# running run_seed0_nscale0.25_D96_stim2_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.8293778
# -0.8293778
# condition  4 / 36000 : (0, 0, 0, 1, 0)
# running run_seed0_nscale0.25_D96_stim4_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.572934
# -0.572934
# condition  5 / 36000 : (0, 0, 0, 1, 1)
# running run_seed0_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.6200665
# -0.6200665
# condition  6 / 36000 : (0, 0, 0, 1, 2)
# running run_seed0_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.6028342
# -0.6028342
# condition  7 / 36000 : (0, 0, 0, 2, 0)
# running run_seed0_nscale0.25_D96_stim6_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.68811095
# 0.68811095
# condition  8 / 36000 : (0, 0, 0, 2, 1)
# running run_seed0_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.59856915
# 0.59856915
# condition  9 / 36000 : (0, 0, 0, 2, 2)
# running run_seed0_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 10000
# mean_comparison = 0.5789309
# 0.5789309
# condition  10 / 36000 : (0, 0, 0, 3, 0)
# running run_seed0_nscale0.25_D96_stim8_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.786456
# 0.786456
# condition  11 / 36000 : (0, 0, 0, 3, 1)
# running run_seed0_nscale0.25_D96_stim8_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.84514165
# 0.84514165
# condition  12 / 36000 : (0, 0, 0, 3, 2)
# running run_seed0_nscale0.25_D96_stim8_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D5', 'D2', 'D7', 'D6']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 0
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 10000
# mean_comparison = 0.7479152
# 0.7479152
# condition  13 / 36000 : (0, 1, 0, 0, 0)
# -0.8778784
# condition  14 / 36000 : (0, 1, 0, 0, 1)
# -0.8100098
# condition  15 / 36000 : (0, 1, 0, 0, 2)
# -0.8297824
# condition  16 / 36000 : (0, 1, 0, 1, 0)
# -0.69126374
# condition  17 / 36000 : (0, 1, 0, 1, 1)
# -0.7229607
# condition  18 / 36000 : (0, 1, 0, 1, 2)
# -0.7002151
# condition  19 / 36000 : (0, 1, 0, 2, 0)
# 0.75994855
# condition  20 / 36000 : (0, 1, 0, 2, 1)
# 0.6915436
# condition  21 / 36000 : (0, 1, 0, 2, 2)
# 0.6763163
# condition  22 / 36000 : (0, 1, 0, 3, 0)
# 0.82588774
# condition  23 / 36000 : (0, 1, 0, 3, 1)
# 0.8612518
# condition  24 / 36000 : (0, 1, 0, 3, 2)
# 0.8847081
# condition  25 / 36000 : (0, 2, 0, 0, 0)
# -0.88762426
# condition  26 / 36000 : (0, 2, 0, 0, 1)
# -0.8687839
# condition  27 / 36000 : (0, 2, 0, 0, 2)
# -0.8651948
# condition  28 / 36000 : (0, 2, 0, 1, 0)
# -0.8096828
# condition  29 / 36000 : (0, 2, 0, 1, 1)
# -0.77909577
# condition  30 / 36000 : (0, 2, 0, 1, 2)
# -0.76672804
# condition  31 / 36000 : (0, 2, 0, 2, 0)
# 0.82560194
# condition  32 / 36000 : (0, 2, 0, 2, 1)
# 0.7931439
# condition  33 / 36000 : (0, 2, 0, 2, 2)
# 0.81429976
# condition  34 / 36000 : (0, 2, 0, 3, 0)
# 0.8954211
# condition  35 / 36000 : (0, 2, 0, 3, 1)
# 0.86528695
# condition  36 / 36000 : (0, 2, 0, 3, 2)
# 0.87404823
# condition  37 / 36000 : (1, 0, 0, 0, 0)
# running run_seed1_nscale0.25_D96_stim2_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.9148642
# -0.9148642
# condition  38 / 36000 : (1, 0, 0, 0, 1)
# running run_seed1_nscale0.25_D96_stim2_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.85650235
# -0.85650235
# condition  39 / 36000 : (1, 0, 0, 0, 2)
# running run_seed1_nscale0.25_D96_stim2_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.86829436
# -0.86829436
# condition  40 / 36000 : (1, 0, 0, 1, 0)
# running run_seed1_nscale0.25_D96_stim4_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.49095163
# -0.49095163
# condition  41 / 36000 : (1, 0, 0, 1, 1)
# running run_seed1_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.54245234
# -0.54245234
# condition  42 / 36000 : (1, 0, 0, 1, 2)
# running run_seed1_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.553323
# -0.553323
# condition  43 / 36000 : (1, 0, 0, 2, 0)
# running run_seed1_nscale0.25_D96_stim6_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.5756269
# 0.5756269
# condition  44 / 36000 : (1, 0, 0, 2, 1)
# running run_seed1_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.6461879
# 0.6461879
# condition  45 / 36000 : (1, 0, 0, 2, 2)
# running run_seed1_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 10000
# mean_comparison = 0.5314192
# 0.5314192
# condition  46 / 36000 : (1, 0, 0, 3, 0)
# running run_seed1_nscale0.25_D96_stim8_nsamples100
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.7524794
# 0.7524794
# condition  47 / 36000 : (1, 0, 0, 3, 1)
# running run_seed1_nscale0.25_D96_stim8_nsamples1000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.89470965
# 0.89470965
# condition  48 / 36000 : (1, 0, 0, 3, 2)
# running run_seed1_nscale0.25_D96_stim8_nsamples10000
# stimuli ['D8', 'D4', 'D3', 'D2', 'D6', 'D5', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 1
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 10000
# mean_comparison = 0.7740685
# 0.7740685
# condition  49 / 36000 : (1, 1, 0, 0, 0)
# -0.7743088
# condition  50 / 36000 : (1, 1, 0, 0, 1)
# -0.8461148
# condition  51 / 36000 : (1, 1, 0, 0, 2)
# -0.86250305
# condition  52 / 36000 : (1, 1, 0, 1, 0)
# -0.6232047
# condition  53 / 36000 : (1, 1, 0, 1, 1)
# -0.6626882
# condition  54 / 36000 : (1, 1, 0, 1, 2)
# -0.71390915
# condition  55 / 36000 : (1, 1, 0, 2, 0)
# 0.69450575
# condition  56 / 36000 : (1, 1, 0, 2, 1)
# 0.73436856
# condition  57 / 36000 : (1, 1, 0, 2, 2)
# 0.7181275
# condition  58 / 36000 : (1, 1, 0, 3, 0)
# 0.8090837
# condition  59 / 36000 : (1, 1, 0, 3, 1)
# 0.84357923
# condition  60 / 36000 : (1, 1, 0, 3, 2)
# 0.82309145
# condition  61 / 36000 : (1, 2, 0, 0, 0)
# -0.9077745
# condition  62 / 36000 : (1, 2, 0, 0, 1)
# -0.8736875
# condition  63 / 36000 : (1, 2, 0, 0, 2)
# -0.8881838
# condition  64 / 36000 : (1, 2, 0, 1, 0)
# -0.690923
# condition  65 / 36000 : (1, 2, 0, 1, 1)
# -0.7762464
# condition  66 / 36000 : (1, 2, 0, 1, 2)
# -0.7994761
# condition  67 / 36000 : (1, 2, 0, 2, 0)
# 0.75763166
# condition  68 / 36000 : (1, 2, 0, 2, 1)
# 0.7916263
# condition  69 / 36000 : (1, 2, 0, 2, 2)
# 0.7864162
# condition  70 / 36000 : (1, 2, 0, 3, 0)
# 0.8648256
# condition  71 / 36000 : (1, 2, 0, 3, 1)
# 0.8847561
# condition  72 / 36000 : (1, 2, 0, 3, 2)
# 0.8596672
# condition  73 / 36000 : (2, 0, 0, 0, 0)
# running run_seed2_nscale0.25_D96_stim2_nsamples100
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.91400826
# -0.91400826
# condition  74 / 36000 : (2, 0, 0, 0, 1)
# running run_seed2_nscale0.25_D96_stim2_nsamples1000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.8975473
# -0.8975473
# condition  75 / 36000 : (2, 0, 0, 0, 2)
# running run_seed2_nscale0.25_D96_stim2_nsamples10000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.8692587
# -0.8692587
# condition  76 / 36000 : (2, 0, 0, 1, 0)
# running run_seed2_nscale0.25_D96_stim4_nsamples100
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.6988383
# -0.6988383
# condition  77 / 36000 : (2, 0, 0, 1, 1)
# running run_seed2_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.6685889
# -0.6685889
# condition  78 / 36000 : (2, 0, 0, 1, 2)
# running run_seed2_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.6769532
# -0.6769532
# condition  79 / 36000 : (2, 0, 0, 2, 0)
# running run_seed2_nscale0.25_D96_stim6_nsamples100
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.6707993
# 0.6707993
# condition  80 / 36000 : (2, 0, 0, 2, 1)
# running run_seed2_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.4656092
# 0.4656092
# condition  81 / 36000 : (2, 0, 0, 2, 2)
# running run_seed2_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 10000
# mean_comparison = 0.5335861
# 0.5335861
# condition  82 / 36000 : (2, 0, 0, 3, 0)
# running run_seed2_nscale0.25_D96_stim8_nsamples100
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.8452487
# 0.8452487
# condition  83 / 36000 : (2, 0, 0, 3, 1)
# running run_seed2_nscale0.25_D96_stim8_nsamples1000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.8083482
# 0.8083482
# condition  84 / 36000 : (2, 0, 0, 3, 2)
# running run_seed2_nscale0.25_D96_stim8_nsamples10000
# stimuli ['D6', 'D3', 'D5', 'D4', 'D8', 'D7', 'D2']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 2
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 10000
# mean_comparison = 0.8770691
# 0.8770691
# condition  85 / 36000 : (2, 1, 0, 0, 0)
# -0.88987076
# condition  86 / 36000 : (2, 1, 0, 0, 1)
# -0.87409866
# condition  87 / 36000 : (2, 1, 0, 0, 2)
# -0.8602826
# condition  88 / 36000 : (2, 1, 0, 1, 0)
# -0.75162673
# condition  89 / 36000 : (2, 1, 0, 1, 1)
# -0.7533329
# condition  90 / 36000 : (2, 1, 0, 1, 2)
# -0.7408986
# condition  91 / 36000 : (2, 1, 0, 2, 0)
# 0.7727293
# condition  92 / 36000 : (2, 1, 0, 2, 1)
# 0.6602242
# condition  93 / 36000 : (2, 1, 0, 2, 2)
# 0.7744215
# condition  94 / 36000 : (2, 1, 0, 3, 0)
# 0.845116
# condition  95 / 36000 : (2, 1, 0, 3, 1)
# 0.85788965
# condition  96 / 36000 : (2, 1, 0, 3, 2)
# 0.8897032
# condition  97 / 36000 : (2, 2, 0, 0, 0)
# -0.8996674
# condition  98 / 36000 : (2, 2, 0, 0, 1)
# -0.9157335
# condition  99 / 36000 : (2, 2, 0, 0, 2)
# -0.8938225
# condition  100 / 36000 : (2, 2, 0, 1, 0)
# -0.8435683
# condition  101 / 36000 : (2, 2, 0, 1, 1)
# -0.80856985
# condition  102 / 36000 : (2, 2, 0, 1, 2)
# -0.78754663
# condition  103 / 36000 : (2, 2, 0, 2, 0)
# 0.830219
# condition  104 / 36000 : (2, 2, 0, 2, 1)
# 0.79321504
# condition  105 / 36000 : (2, 2, 0, 2, 2)
# 0.8056932
# condition  106 / 36000 : (2, 2, 0, 3, 0)
# 0.8904923
# condition  107 / 36000 : (2, 2, 0, 3, 1)
# 0.8694861
# condition  108 / 36000 : (2, 2, 0, 3, 2)
# 0.86933655
# condition  109 / 36000 : (3, 0, 0, 0, 0)
# running run_seed3_nscale0.25_D96_stim2_nsamples100
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.71541137
# -0.71541137
# condition  110 / 36000 : (3, 0, 0, 0, 1)
# running run_seed3_nscale0.25_D96_stim2_nsamples1000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.7462916
# -0.7462916
# condition  111 / 36000 : (3, 0, 0, 0, 2)
# running run_seed3_nscale0.25_D96_stim2_nsamples10000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.8460565
# -0.8460565
# condition  112 / 36000 : (3, 0, 0, 1, 0)
# running run_seed3_nscale0.25_D96_stim4_nsamples100
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.36854938
# -0.36854938
# condition  113 / 36000 : (3, 0, 0, 1, 1)
# running run_seed3_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.58799386
# -0.58799386
# condition  114 / 36000 : (3, 0, 0, 1, 2)
# running run_seed3_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.61898184
# -0.61898184
# condition  115 / 36000 : (3, 0, 0, 2, 0)
# running run_seed3_nscale0.25_D96_stim6_nsamples100
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.45654374
# 0.45654374
# condition  116 / 36000 : (3, 0, 0, 2, 1)
# running run_seed3_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.5992239
# 0.5992239
# condition  117 / 36000 : (3, 0, 0, 2, 2)
# running run_seed3_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 10000
# mean_comparison = 0.7227199
# 0.7227199
# condition  118 / 36000 : (3, 0, 0, 3, 0)
# running run_seed3_nscale0.25_D96_stim8_nsamples100
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.70965743
# 0.70965743
# condition  119 / 36000 : (3, 0, 0, 3, 1)
# running run_seed3_nscale0.25_D96_stim8_nsamples1000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.71910214
# 0.71910214
# condition  120 / 36000 : (3, 0, 0, 3, 2)
# running run_seed3_nscale0.25_D96_stim8_nsamples10000
# stimuli ['D6', 'D8', 'D7', 'D5', 'D3', 'D2', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 3
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 10000
# mean_comparison = 0.89654875
# 0.89654875
# condition  121 / 36000 : (3, 1, 0, 0, 0)
# -0.70222884
# condition  122 / 36000 : (3, 1, 0, 0, 1)
# -0.8401514
# condition  123 / 36000 : (3, 1, 0, 0, 2)
# -0.8944624
# condition  124 / 36000 : (3, 1, 0, 1, 0)
# -0.6159279
# condition  125 / 36000 : (3, 1, 0, 1, 1)
# -0.7592578
# condition  126 / 36000 : (3, 1, 0, 1, 2)
# -0.7452883
# condition  127 / 36000 : (3, 1, 0, 2, 0)
# 0.59781414
# condition  128 / 36000 : (3, 1, 0, 2, 1)
# 0.77741045
# condition  129 / 36000 : (3, 1, 0, 2, 2)
# 0.7241291
# condition  130 / 36000 : (3, 1, 0, 3, 0)
# 0.82954377
# condition  131 / 36000 : (3, 1, 0, 3, 1)
# 0.8261131
# condition  132 / 36000 : (3, 1, 0, 3, 2)
# 0.8877217
# condition  133 / 36000 : (3, 2, 0, 0, 0)
# -0.77496666
# condition  134 / 36000 : (3, 2, 0, 0, 1)
# -0.8699561
# condition  135 / 36000 : (3, 2, 0, 0, 2)
# -0.8832019
# condition  136 / 36000 : (3, 2, 0, 1, 0)
# -0.69904417
# condition  137 / 36000 : (3, 2, 0, 1, 1)
# -0.7909767
# condition  138 / 36000 : (3, 2, 0, 1, 2)
# -0.80169463
# condition  139 / 36000 : (3, 2, 0, 2, 0)
# 0.66395646
# condition  140 / 36000 : (3, 2, 0, 2, 1)
# 0.8052637
# condition  141 / 36000 : (3, 2, 0, 2, 2)
# 0.77940106
# condition  142 / 36000 : (3, 2, 0, 3, 0)
# 0.8124287
# condition  143 / 36000 : (3, 2, 0, 3, 1)
# 0.8577128
# condition  144 / 36000 : (3, 2, 0, 3, 2)
# 0.89590335
# condition  145 / 36000 : (4, 0, 0, 0, 0)
# running run_seed4_nscale0.25_D96_stim2_nsamples100
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.85466355
# -0.85466355
# condition  146 / 36000 : (4, 0, 0, 0, 1)
# running run_seed4_nscale0.25_D96_stim2_nsamples1000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.85780925
# -0.85780925
# condition  147 / 36000 : (4, 0, 0, 0, 2)
# running run_seed4_nscale0.25_D96_stim2_nsamples10000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.8854277
# -0.8854277
# condition  148 / 36000 : (4, 0, 0, 1, 0)
# running run_seed4_nscale0.25_D96_stim4_nsamples100
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.65426874
# -0.65426874
# condition  149 / 36000 : (4, 0, 0, 1, 1)
# running run_seed4_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.48277867
# -0.48277867
# condition  150 / 36000 : (4, 0, 0, 1, 2)
# running run_seed4_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.5469408
# -0.5469408
# condition  151 / 36000 : (4, 0, 0, 2, 0)
# running run_seed4_nscale0.25_D96_stim6_nsamples100
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.5227162
# 0.5227162
# condition  152 / 36000 : (4, 0, 0, 2, 1)
# running run_seed4_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.5198113
# 0.5198113
# condition  153 / 36000 : (4, 0, 0, 2, 2)
# running run_seed4_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 10000
# mean_comparison = 0.5281083
# 0.5281083
# condition  154 / 36000 : (4, 0, 0, 3, 0)
# running run_seed4_nscale0.25_D96_stim8_nsamples100
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.8751182
# 0.8751182
# condition  155 / 36000 : (4, 0, 0, 3, 1)
# running run_seed4_nscale0.25_D96_stim8_nsamples1000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.78838456
# 0.78838456
# condition  156 / 36000 : (4, 0, 0, 3, 2)
# running run_seed4_nscale0.25_D96_stim8_nsamples10000
# stimuli ['D6', 'D8', 'D5', 'D2', 'D3', 'D7', 'D4']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 4
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 10000
# mean_comparison = 0.9143015
# 0.9143015
# condition  157 / 36000 : (4, 1, 0, 0, 0)
# -0.8615474
# condition  158 / 36000 : (4, 1, 0, 0, 1)
# -0.83162504
# condition  159 / 36000 : (4, 1, 0, 0, 2)
# -0.85659516
# condition  160 / 36000 : (4, 1, 0, 1, 0)
# -0.7944439
# condition  161 / 36000 : (4, 1, 0, 1, 1)
# -0.70988786
# condition  162 / 36000 : (4, 1, 0, 1, 2)
# -0.6921762
# condition  163 / 36000 : (4, 1, 0, 2, 0)
# 0.63522863
# condition  164 / 36000 : (4, 1, 0, 2, 1)
# 0.72272307
# condition  165 / 36000 : (4, 1, 0, 2, 2)
# 0.74991345
# condition  166 / 36000 : (4, 1, 0, 3, 0)
# 0.8714058
# condition  167 / 36000 : (4, 1, 0, 3, 1)
# 0.8379376
# condition  168 / 36000 : (4, 1, 0, 3, 2)
# 0.8118592
# condition  169 / 36000 : (4, 2, 0, 0, 0)
# -0.88985854
# condition  170 / 36000 : (4, 2, 0, 0, 1)
# -0.8666094
# condition  171 / 36000 : (4, 2, 0, 0, 2)
# -0.8791134
# condition  172 / 36000 : (4, 2, 0, 1, 0)
# -0.8426235
# condition  173 / 36000 : (4, 2, 0, 1, 1)
# -0.7854777
# condition  174 / 36000 : (4, 2, 0, 1, 2)
# -0.7578087
# condition  175 / 36000 : (4, 2, 0, 2, 0)
# 0.73651004
# condition  176 / 36000 : (4, 2, 0, 2, 1)
# 0.78091776
# condition  177 / 36000 : (4, 2, 0, 2, 2)
# 0.8075518
# condition  178 / 36000 : (4, 2, 0, 3, 0)
# 0.87850523
# condition  179 / 36000 : (4, 2, 0, 3, 1)
# 0.85729676
# condition  180 / 36000 : (4, 2, 0, 3, 2)
# 0.8356106
# condition  181 / 36000 : (5, 0, 0, 0, 0)
# running run_seed5_nscale0.25_D96_stim2_nsamples100
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 100
# mean_comparison = -0.8353043
# -0.8353043
# condition  182 / 36000 : (5, 0, 0, 0, 1)
# running run_seed5_nscale0.25_D96_stim2_nsamples1000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 1000
# mean_comparison = -0.8078584
# -0.8078584
# condition  183 / 36000 : (5, 0, 0, 0, 2)
# running run_seed5_nscale0.25_D96_stim2_nsamples10000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.83431154
# -0.83431154
# condition  184 / 36000 : (5, 0, 0, 1, 0)
# running run_seed5_nscale0.25_D96_stim4_nsamples100
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = -0.4763317
# -0.4763317
# condition  185 / 36000 : (5, 0, 0, 1, 1)
# running run_seed5_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.57315606
# -0.57315606
# condition  186 / 36000 : (5, 0, 0, 1, 2)
# running run_seed5_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.6593816
# -0.6593816
# condition  187 / 36000 : (5, 0, 0, 2, 0)
# running run_seed5_nscale0.25_D96_stim6_nsamples100
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.7351747
# 0.7351747
# condition  188 / 36000 : (5, 0, 0, 2, 1)
# running run_seed5_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.65213805
# 0.65213805
# condition  189 / 36000 : (5, 0, 0, 2, 2)
# running run_seed5_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 10000
# mean_comparison = 0.6138957
# 0.6138957
# condition  190 / 36000 : (5, 0, 0, 3, 0)
# running run_seed5_nscale0.25_D96_stim8_nsamples100
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 100
# mean_comparison = 0.8763426
# 0.8763426
# condition  191 / 36000 : (5, 0, 0, 3, 1)
# running run_seed5_nscale0.25_D96_stim8_nsamples1000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 1000
# mean_comparison = 0.8472673
# 0.8472673
# condition  192 / 36000 : (5, 0, 0, 3, 2)
# running run_seed5_nscale0.25_D96_stim8_nsamples10000
# stimuli ['D8', 'D4', 'D6', 'D3', 'D2', 'D7', 'D5']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 5
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 8
# n_samples = 10000
# mean_comparison = 0.8364485
# 0.8364485
# condition  193 / 36000 : (5, 1, 0, 0, 0)
# -0.8291762
# condition  194 / 36000 : (5, 1, 0, 0, 1)
# -0.84556997
# condition  195 / 36000 : (5, 1, 0, 0, 2)
# -0.8853619
# condition  196 / 36000 : (5, 1, 0, 1, 0)
# -0.61417603
# condition  197 / 36000 : (5, 1, 0, 1, 1)
# -0.7716184
# condition  198 / 36000 : (5, 1, 0, 1, 2)
# -0.73695326
# condition  199 / 36000 : (5, 1, 0, 2, 0)
# 0.7542981
# condition  200 / 36000 : (5, 1, 0, 2, 1)
# 0.675445
# condition  201 / 36000 : (5, 1, 0, 2, 2)
# 0.68305254
# condition  202 / 36000 : (5, 1, 0, 3, 0)
# 0.87835455
# condition  203 / 36000 : (5, 1, 0, 3, 1)
# 0.8696595
# condition  204 / 36000 : (5, 1, 0, 3, 2)
# 0.8497815
# condition  205 / 36000 : (5, 2, 0, 0, 0)
# -0.87872607
# condition  206 / 36000 : (5, 2, 0, 0, 1)
# -0.84791625
# condition  207 / 36000 : (5, 2, 0, 0, 2)
# -0.8490988
# condition  208 / 36000 : (5, 2, 0, 1, 0)
# -0.7417204
# condition  209 / 36000 : (5, 2, 0, 1, 1)
# -0.7793581
# condition  210 / 36000 : (5, 2, 0, 1, 2)
# -0.76619637
# condition  211 / 36000 : (5, 2, 0, 2, 0)
# 0.8309545
# condition  212 / 36000 : (5, 2, 0, 2, 1)
# 0.7850232
# condition  213 / 36000 : (5, 2, 0, 2, 2)
# 0.824637
# condition  214 / 36000 : (5, 2, 0, 3, 0)
# 0.8954642
# condition  215 / 36000 : (5, 2, 0, 3, 1)
# 0.8767267
# condition  216 / 36000 : (5, 2, 0, 3, 2)
# ...
# compare shape (200, 1)
# seed = 22
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 2
# n_samples = 10000
# mean_comparison = -0.7900247
# -0.7900247
# condition  796 / 36000 : (22, 0, 0, 1, 0)
# running run_seed22_nscale0.25_D96_stim4_nsamples100
# stimuli ['D3', 'D4', 'D5', 'D2', 'D8', 'D6', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 22
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 100
# mean_comparison = 0.051800214
# 0.051800214
# condition  797 / 36000 : (22, 0, 0, 1, 1)
# running run_seed22_nscale0.25_D96_stim4_nsamples1000
# stimuli ['D3', 'D4', 'D5', 'D2', 'D8', 'D6', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 22
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 1000
# mean_comparison = -0.6772057
# -0.6772057
# condition  798 / 36000 : (22, 0, 0, 1, 2)
# running run_seed22_nscale0.25_D96_stim4_nsamples10000
# stimuli ['D3', 'D4', 'D5', 'D2', 'D8', 'D6', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 22
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 4
# n_samples = 10000
# mean_comparison = -0.6566617
# -0.6566617
# condition  799 / 36000 : (22, 0, 0, 2, 0)
# running run_seed22_nscale0.25_D96_stim6_nsamples100
# stimuli ['D3', 'D4', 'D5', 'D2', 'D8', 'D6', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 22
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 100
# mean_comparison = 0.7392178
# 0.7392178
# condition  800 / 36000 : (22, 0, 0, 2, 1)
# running run_seed22_nscale0.25_D96_stim6_nsamples1000
# stimuli ['D3', 'D4', 'D5', 'D2', 'D8', 'D6', 'D7']
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# compare shape (200, 1)
# seed = 22
# backend = 'nengo_ocl'
# dt = 0.001
# neuron_type = 'default'
# n_neurons_scale = 0.25
# s_evidence = 20
# D = 96
# integrator_reset = True
# T = 0.2
# stimulus = 6
# n_samples = 1000
# mean_comparison = 0.6434304
# 0.6434304
# condition  801 / 36000 : (22, 0, 0, 2, 2)
# running run_seed22_nscale0.25_D96_stim6_nsamples10000
# stimuli ['D3', 'D4', 'D5', 'D2', 'D8', 'D6', 'D7']
# Traceback (most recent call last):
#   File "<ipython-input-6-612c900842c3>", line 17, in <module>
#     mean_comparison = pickle.load(open(data_dir+'/'+data_filename, "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: 'evaluate_compare/all/run_seed22_nscale0.25_D96_stim6_nsamples10000'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py", line 120, in build_network
#     model.decoder_cache.shrink()
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 619, in shrink
#     self.remove_file(path)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 369, in __exit__
#     self.sync()
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 441, in sync
#     self._index = {k: v for k, v in iteritems(self._index)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 442, in <dictcomp>
#     if v[0] not in self._removed_files}
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-612c900842c3>", line 29, in <module>
#     data_filename=data_filename,
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/pytry-0.9.2-py3.7.egg/pytry/trial.py", line 91, in run
#     result = self.execute_trial(p)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/pytry-0.9.2-py3.7.egg/pytry/nengo.py", line 112, in execute_trial
#     self.sim = Simulator(model, dt=p.dt, **extra_args)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_ocl/simulator.py", line 238, in __init__
#     self.model.build(network)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py", line 123, in build
#     built = self.builder.build(self, obj, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py", line 218, in build
#     return cls.builders[obj_cls](model, obj, *args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py", line 124, in build_network
#     model.build_callback = None
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 515, in __exit__
#     rval = self._index.__exit__(exc_type, exc_value, traceback)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 369, in __exit__
#     self.sync()
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 431, in sync
#     self._load_index_file()
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py", line 290, in _load_index_file
#     self._index = pickle.load(f)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/home/ubuntu/anaconda3/envs/CTN/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-612c900842c3> in <module>
#      16     try:
# ---> 17         mean_comparison = pickle.load(open(data_dir+'/'+data_filename, "rb"))
#      18
#
# FileNotFoundError: [Errno 2] No such file or directory: 'evaluate_compare/all/run_seed22_nscale0.25_D96_stim6_nsamples10000'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     119         if context is model.decoder_cache:
# --> 120             model.decoder_cache.shrink()
#     121
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in shrink(self, limit)
#     618                     excess -= size
# --> 619                     self.remove_file(path)
#     620         except TimeoutError:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in __exit__(self, exc_type, exc_value, traceback)
#     368     def __exit__(self, exc_type, exc_value, traceback):
# --> 369         self.sync()
#     370
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in sync(self)
#     440                     del self._index[key]
# --> 441                 self._index = {k: v for k, v in iteritems(self._index)
#     442                                if v[0] not in self._removed_files}
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in <dictcomp>(.0)
#     441                 self._index = {k: v for k, v in iteritems(self._index)
# --> 442                                if v[0] not in self._removed_files}
#     443
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3330                 else:
# -> 3331                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3332             finally:
#
# <ipython-input-6-612c900842c3> in <module>
#      28                 data_dir=data_dir,
# ---> 29                 data_filename=data_filename,
#      30             )['mean_comparison']
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/pytry-0.9.2-py3.7.egg/pytry/trial.py in run(self, **kwargs)
#      90
# ---> 91         result = self.execute_trial(p)
#      92
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/pytry-0.9.2-py3.7.egg/pytry/nengo.py in execute_trial(self, p)
#     111             else:
# --> 112                 self.sim = Simulator(model, dt=p.dt, **extra_args)
#     113
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo_ocl/simulator.py in __init__(self, network, dt, seed, model, context, n_prealloc_probes, profiling, if_python_code, planner, progress_bar)
#     237                 # Build the network into the model
# --> 238                 self.model.build(network)
#     239
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(self, obj, *args, **kwargs)
#     122         """
# --> 123         built = self.builder.build(self, obj, *args, **kwargs)
#     124         if self.build_callback is not None:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/builder.py in build(cls, model, obj, *args, **kwargs)
#     217
# --> 218         return cls.builders[obj_cls](model, obj, *args, **kwargs)
#     219
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/builder/network.py in build_network(model, network, progress)
#     123             progress.step()
# --> 124             model.build_callback = None
#     125
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in __exit__(self, exc_type, exc_value, traceback)
#     514         if self._index is not None:
# --> 515             rval = self._index.__exit__(exc_type, exc_value, traceback)
#     516             return rval
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in __exit__(self, exc_type, exc_value, traceback)
#     368     def __exit__(self, exc_type, exc_value, traceback):
# --> 369         self.sync()
#     370
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in sync(self)
#     430                 try:
# --> 431                     self._load_index_file()
#     432                 except IOError as err:
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/nengo/cache.py in _load_index_file(self)
#     289                         "Unsupported cache index file format.")
# --> 290                 self._index = pickle.load(f)
#     291             else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3346             if result is not None:
#    3347                 result.error_in_exec = sys.exc_info()[1]
# -> 3348             self.showtraceback(running_compiled_code=True)
#    3349         else:
#    3350             outflag = False
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1413             self.tb = tb
#    1414         return FormattedTB.structured_traceback(
# -> 1415             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1416
#    1417
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1313             # Verbose modes need a full traceback
#    1314             return VerboseTB.structured_traceback(
# -> 1315                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1316             )
#    1317         elif mode == 'Minimal':
#
# ~/anaconda3/envs/CTN/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1181         exception = self.get_parts_of_chained_exception(evalue)
#    1182         if exception:
# -> 1183             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1184             etype, evalue, etb = exception
#    1185         else:
#
# TypeError: can only concatenate str (not "list") to str
